# %%
from nilearn import datasets
import pandas as pd
from nilearn import plotting
from nilearn.interfaces.fmriprep import load_confounds_strategy
from nilearn.maskers import NiftiMapsMasker,NiftiLabelsMasker
from nilearn.connectome import ConnectivityMeasure
import os
from pathlib import Path
import numpy as np
import abagen
from dipy.io.image import load_nifti
import nibabel as nib

# %%
freesurfer_path ="/workspace/home/datasets/mri/schizo_datasets/COBRE/COBRE_freesurfer/"

# %%
path =Path(freesurfer_path) / 'A00025969/mri/FS_label.nii.gz'

# %%
fs_prefix ='FS_label.nii.gz'

# %%
atlas = abagen.fetch_desikan_killiany()

# %%
atlas['image']
# Out:
# '/opt/miniconda-latest/lib/python3.8/site-packages/abagen/data/atlas-desikankilliany.nii.gz'

# %%
desikan_killiany_info =pd.read_csv(atlas['info'])

# %%
# Locate the data of the first subject
data_path = '/workspace/home/datasets/mri/schizo_datasets/COBRE/COBRE_fmriprep/'

# %%
#atlas = datasets.fetch_atlas_schaefer_2018()

# %%
def preproc_atlas(atlas_data):
    new_atlas_data =atlas_data.copy()
    for elem, new_elem in zip(np.unique(atlas_data),list(range(np.unique(atlas_data).shape[0]))):
        new_atlas_data[new_atlas_data==elem]=new_elem
    return new_atlas_data

# %%
# Define plot function
def show_slices(image, axis1="x", axis2="y", axis3="z"):
    slice_0 = image[round(len(image[0])/2), :, :]
    slice_1 = image[:, round(len(image[1])/2), :]
    slice_2 = image[:, :, round(len(image[2])/2)]
    image = ([slice_0, slice_1, slice_2])
    fig, axes = plt.subplots(1, len(image), figsize=[15,15])
    for i, slice in enumerate(image):
        axes[i].imshow(slice.T, cmap="gray", origin="lower")
        axes[0].set(xlabel=axis2, ylabel=axis3)
        axes[1].set(xlabel=axis1, ylabel=axis3)
        axes[2].set(xlabel=axis1, ylabel=axis2)
    plt.show()
    
def flatten_freesurfer_stats(path):
    """
        Parses FreeSurfer statistics then flattens included table of brain structure features into 1-row table as DataFrame.
    """

    from os.path import basename
    import pandas as pd
    from plumbum.colors import fatal

    try:
        # Get line with column names from file of FreeSurfer statistics.
        ColHeader = next(filter(lambda line: line.startswith('# ColHeaders'), open(path).readlines()))
        # Ignore first '#', 'ColHeaders'. Leave column names only.
        names = ColHeader.split()[2:] 
        data = pd.read_csv(path, names=names, comment='#', delim_whitespace=True, dtype=str)
#         columns = [col for col in filter(
#             lambda column: column not in ['Index', 'SegId', 'StructName'],
#             data.columns
#         )]
#         StructNames = data['StructName']
#         data = pd.DataFrame(data[columns].T.values.flatten()).T

#         # Get prefix (e.g. 'rh') from file name like ``rh.aparc.stats``
#         # as suffix for names of 1-row columns had been flattened from DataFrame.
#         filename = basename(path).split('.')
#         suffix = [filename[0]] if len(filename) > 2 else [] # There is no prefix from file name like ``aseg.stats``
#         data.columns = ['_'.join([prefix, infix] + suffix) for infix in columns for prefix in StructNames]
        return data[['SegId','StructName']]
    except StopIteration:
        print(fatal | "There is no header with column names starting with ColHeaders in the file", path)
    except FileNotFoundError as e:
        print(fatal | str(e))
    except KeyError as e:
        print(fatal | "There is no column", str(e))
    return pd.DataFrame()

# %%
def get_dtk_labels(atlas_data):
    data =flatten_freesurfer_stats('column_names.txt')
    data['SegId'] =data['SegId'].astype(int)
    data=data.drop_duplicates(subset=['SegId'])
    labels =data.loc[data.SegId.isin(np.unique(atlas_data).tolist())]['StructName'].to_list()
    return labels

# %%
def extract_correlation_pipe(func,subj, atlas):
    print("extraction: ")
    # Loading atlas image stored in 'maps'
    atlas_filename = Path(freesurfer_path) / f'{subj.split("-")[-1]}/mri/aparc.DKTatlas+aseg.nii'
    # Loading atlas data stored in 'labels'
    
    atlas_data, affine, _ =load_nifti(atlas_filename, return_img=True)
    
    labels =get_dtk_labels(atlas_data)[1:]
    print(atlas_data.shape)
    print(labels)
    print("labels: ", len(labels))
    
    
    confounds_simple, mask =load_confounds_strategy(func)

    # masker = NiftiMapsMasker(maps_img=atlas_filename, standardize=True,
    #                      memory='nilearn_cache', verbose=5)
    # from nilearn.maskers import NiftiLabelsMasker
    masker = NiftiLabelsMasker(labels_img=atlas_filename, standardize=True, resampling_target='labels',
                           memory='nilearn_cache', verbose=5)
    
    time_series = masker.fit_transform(func, confounds =confounds_simple)
    print(time_series.shape)
    
    correlation_measure = ConnectivityMeasure(kind='correlation')
    correlation_matrix = correlation_measure.fit_transform([time_series])[0]
    np.fill_diagonal(correlation_matrix, 0)
    
    print(correlation_matrix.shape)
    data =pd.DataFrame(correlation_matrix, columns=labels, index =labels)
    corr_dict ={}
    for i, column in enumerate(data.columns):
        for j in data.columns[:i]:
            corr_value =data.loc[j,column]
            corr_dict[f'{j}-{column}'] =corr_value
    return  corr_dict,data, pd.DataFrame(time_series,columns=labels)

# %%
len(os.listdir(data_path))
# Out:
# 333

# %%
errrors =0
corr_array =[]
for subj in os.listdir(data_path):
            brain_path =Path(f'{data_path}/{subj}/func/{subj}_task-rest_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz')
            if brain_path.exists():
                try:
                    print(str(brain_path))
                    print("start")
                    corr_dict, data,time_series =extract_correlation_pipe(str(brain_path),subj, atlas)

                    time_series.to_csv(f"results/cobre_dk_big/{subj}_embed.csv")
                    data.to_csv(f"results/cobre_dk_big/{subj}.csv")
                    corr_dict["id"] =subj
                    corr_array.append(corr_dict)
                except Exception as e: 
                    print(e)
# Out:
# /workspace/home/datasets/mri/schizo_datasets/COBRE/COBRE_fmriprep/sub-A00000838/func/sub-A00000838_task-rest_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# start
# extraction:
# (256, 256, 256)
# ['Left-Cerebral-White-Matter', 'Left-Cerebral-Cortex', 'Left-Lateral-Ventricle', 'Left-Inf-Lat-Vent', 'Left-Cerebellum-White-Matter', 'Left-Cerebellum-Cortex', 'Left-Thalamus-Proper*', 'Left-Caudate', 'Left-Putamen', 'Left-Pallidum', '3rd-Ventricle', '4th-Ventricle', 'Brain-Stem', 'Left-Hippocampus', 'Left-Amygdala', 'CSF', 'Left-Accumbens-area', 'Left-VentralDC', 'Left-vessel', 'Left-choroid-plexus', 'Right-Cerebral-White-Matter', 'Right-Cerebral-Cortex', 'Right-Lateral-Ventricle', 'Right-Inf-Lat-Vent', 'Right-Cerebellum-White-Matter', 'Right-Cerebellum-Cortex', 'Right-Thalamus-Proper*', 'Right-Caudate', 'Right-Putamen', 'Right-Pallidum', 'Right-Hippocampus', 'Right-Amygdala', 'Right-Accumbens-area', 'Right-VentralDC', 'Right-vessel', 'Right-choroid-plexus', 'WM-hypointensities', 'Optic-Chiasm', 'CC_Posterior', 'CC_Mid_Posterior', 'CC_Central', 'CC_Mid_Anterior', 'CC_Anterior', 'ctx-lh-unknown', 'ctx-lh-caudalanteriorcingulate', 'ctx-lh-caudalmiddlefrontal', 'ctx-lh-cuneus', 'ctx-lh-entorhinal', 'ctx-lh-fusiform', 'ctx-lh-inferiorparietal', 'ctx-lh-inferiortemporal', 'ctx-lh-isthmuscingulate', 'ctx-lh-lateraloccipital', 'ctx-lh-lateralorbitofrontal', 'ctx-lh-lingual', 'ctx-lh-medialorbitofrontal', 'ctx-lh-middletemporal', 'ctx-lh-parahippocampal', 'ctx-lh-paracentral', 'ctx-lh-parsopercularis', 'ctx-lh-parsorbitalis', 'ctx-lh-parstriangularis', 'ctx-lh-pericalcarine', 'ctx-lh-postcentral', 'ctx-lh-posteriorcingulate', 'ctx-lh-precentral', 'ctx-lh-precuneus', 'ctx-lh-rostralanteriorcingulate', 'ctx-lh-rostralmiddlefrontal', 'ctx-lh-superiorfrontal', 'ctx-lh-superiorparietal', 'ctx-lh-superiortemporal', 'ctx-lh-supramarginal', 'ctx-lh-transversetemporal', 'ctx-lh-insula', 'ctx-rh-unknown', 'ctx-rh-caudalanteriorcingulate', 'ctx-rh-caudalmiddlefrontal', 'ctx-rh-cuneus', 'ctx-rh-entorhinal', 'ctx-rh-fusiform', 'ctx-rh-inferiorparietal', 'ctx-rh-inferiortemporal', 'ctx-rh-isthmuscingulate', 'ctx-rh-lateraloccipital', 'ctx-rh-lateralorbitofrontal', 'ctx-rh-lingual', 'ctx-rh-medialorbitofrontal', 'ctx-rh-middletemporal', 'ctx-rh-parahippocampal', 'ctx-rh-paracentral', 'ctx-rh-parsopercularis', 'ctx-rh-parsorbitalis', 'ctx-rh-parstriangularis', 'ctx-rh-pericalcarine', 'ctx-rh-postcentral', 'ctx-rh-posteriorcingulate', 'ctx-rh-precentral', 'ctx-rh-precuneus', 'ctx-rh-rostralanteriorcingulate', 'ctx-rh-rostralmiddlefrontal', 'ctx-rh-superiorfrontal', 'ctx-rh-superiorparietal', 'ctx-rh-superiortemporal', 'ctx-rh-supramarginal', 'ctx-rh-transversetemporal', 'ctx-rh-insula']
# labels:  107
# [NiftiLabelsMasker.wrapped] loading data from /workspace/home/datasets/mri/schizo_datasets/COBRE/COBRE_freesurfer/A00000838/mri/aparc.DKTatlas+aseg.nii
# [Memory]0.1s, 0.0min    : Loading _filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# (150, 107)
# (107, 107)
# /workspace/home/datasets/mri/schizo_datasets/COBRE/COBRE_fmriprep/sub-A00036844/func/sub-A00036844_task-rest_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# start
# extraction:
# (256, 256, 256)
# ['Left-Cerebral-White-Matter', 'Left-Lateral-Ventricle', 'Left-Inf-Lat-Vent', 'Left-Cerebellum-White-Matter', 'Left-Cerebellum-Cortex', 'Left-Thalamus-Proper*', 'Left-Caudate', 'Left-Putamen', 'Left-Pallidum', '3rd-Ventricle', '4th-Ventricle', 'Brain-Stem', 'Left-Hippocampus', 'Left-Amygdala', 'CSF', 'Left-Accumbens-area', 'Left-VentralDC', 'Left-vessel', 'Left-choroid-plexus', 'Right-Cerebral-White-Matter', 'Right-Lateral-Ventricle', 'Right-Inf-Lat-Vent', 'Right-Cerebellum-White-Matter', 'Right-Cerebellum-Cortex', 'Right-Thalamus-Proper*', 'Right-Caudate', 'Right-Putamen', 'Right-Pallidum', 'Right-Hippocampus', 'Right-Amygdala', 'Right-Accumbens-area', 'Right-VentralDC', 'Right-vessel', 'Right-choroid-plexus', 'WM-hypointensities', 'Optic-Chiasm', 'CC_Posterior', 'CC_Mid_Posterior', 'CC_Central', 'CC_Mid_Anterior', 'CC_Anterior', 'ctx-lh-unknown', 'ctx-lh-caudalanteriorcingulate', 'ctx-lh-caudalmiddlefrontal', 'ctx-lh-cuneus', 'ctx-lh-entorhinal', 'ctx-lh-fusiform', 'ctx-lh-inferiorparietal', 'ctx-lh-inferiortemporal', 'ctx-lh-isthmuscingulate', 'ctx-lh-lateraloccipital', 'ctx-lh-lateralorbitofrontal', 'ctx-lh-lingual', 'ctx-lh-medialorbitofrontal', 'ctx-lh-middletemporal', 'ctx-lh-parahippocampal', 'ctx-lh-paracentral', 'ctx-lh-parsopercularis', 'ctx-lh-parsorbitalis', 'ctx-lh-parstriangularis', 'ctx-lh-pericalcarine', 'ctx-lh-postcentral', 'ctx-lh-posteriorcingulate', 'ctx-lh-precentral', 'ctx-lh-precuneus', 'ctx-lh-rostralanteriorcingulate', 'ctx-lh-rostralmiddlefrontal', 'ctx-lh-superiorfrontal', 'ctx-lh-superiorparietal', 'ctx-lh-superiortemporal', 'ctx-lh-supramarginal', 'ctx-lh-transversetemporal', 'ctx-lh-insula', 'ctx-rh-unknown', 'ctx-rh-caudalanteriorcingulate', 'ctx-rh-caudalmiddlefrontal', 'ctx-rh-cuneus', 'ctx-rh-entorhinal', 'ctx-rh-fusiform', 'ctx-rh-inferiorparietal', 'ctx-rh-inferiortemporal', 'ctx-rh-isthmuscingulate', 'ctx-rh-lateraloccipital', 'ctx-rh-lateralorbitofrontal', 'ctx-rh-lingual', 'ctx-rh-medialorbitofrontal', 'ctx-rh-middletemporal', 'ctx-rh-parahippocampal', 'ctx-rh-paracentral', 'ctx-rh-parsopercularis', 'ctx-rh-parsorbitalis', 'ctx-rh-parstriangularis', 'ctx-rh-pericalcarine', 'ctx-rh-postcentral', 'ctx-rh-posteriorcingulate', 'ctx-rh-precentral', 'ctx-rh-precuneus', 'ctx-rh-rostralanteriorcingulate', 'ctx-rh-rostralmiddlefrontal', 'ctx-rh-superiorfrontal', 'ctx-rh-superiorparietal', 'ctx-rh-superiortemporal', 'ctx-rh-supramarginal', 'ctx-rh-transversetemporal', 'ctx-rh-insula']
# labels:  105
# [NiftiLabelsMasker.wrapped] loading data from /workspace/home/datasets/mri/schizo_datasets/COBRE/COBRE_freesurfer/A00036844/mri/aparc.DKTatlas+aseg.nii
# [Memory]0.1s, 0.0min    : Loading _filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# (150, 105)
# (105, 105)
# /workspace/home/datasets/mri/schizo_datasets/COBRE/COBRE_fmriprep/sub-A00016197/func/sub-A00016197_task-rest_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# start
# extraction:
# (256, 256, 256)
# ['Left-Cerebral-White-Matter', 'Left-Lateral-Ventricle', 'Left-Inf-Lat-Vent', 'Left-Cerebellum-White-Matter', 'Left-Cerebellum-Cortex', 'Left-Thalamus-Proper*', 'Left-Caudate', 'Left-Putamen', 'Left-Pallidum', '3rd-Ventricle', '4th-Ventricle', 'Brain-Stem', 'Left-Hippocampus', 'Left-Amygdala', 'CSF', 'Left-Accumbens-area', 'Left-VentralDC', 'Left-vessel', 'Left-choroid-plexus', 'Right-Cerebral-White-Matter', 'Right-Lateral-Ventricle', 'Right-Inf-Lat-Vent', 'Right-Cerebellum-White-Matter', 'Right-Cerebellum-Cortex', 'Right-Thalamus-Proper*', 'Right-Caudate', 'Right-Putamen', 'Right-Pallidum', 'Right-Hippocampus', 'Right-Amygdala', 'Right-Accumbens-area', 'Right-VentralDC', 'Right-vessel', 'Right-choroid-plexus', 'WM-hypointensities', 'Optic-Chiasm', 'CC_Posterior', 'CC_Mid_Posterior', 'CC_Central', 'CC_Mid_Anterior', 'CC_Anterior', 'ctx-lh-unknown', 'ctx-lh-caudalanteriorcingulate', 'ctx-lh-caudalmiddlefrontal', 'ctx-lh-cuneus', 'ctx-lh-entorhinal', 'ctx-lh-fusiform', 'ctx-lh-inferiorparietal', 'ctx-lh-inferiortemporal', 'ctx-lh-isthmuscingulate', 'ctx-lh-lateraloccipital', 'ctx-lh-lateralorbitofrontal', 'ctx-lh-lingual', 'ctx-lh-medialorbitofrontal', 'ctx-lh-middletemporal', 'ctx-lh-parahippocampal', 'ctx-lh-paracentral', 'ctx-lh-parsopercularis', 'ctx-lh-parsorbitalis', 'ctx-lh-parstriangularis', 'ctx-lh-pericalcarine', 'ctx-lh-postcentral', 'ctx-lh-posteriorcingulate', 'ctx-lh-precentral', 'ctx-lh-precuneus', 'ctx-lh-rostralanteriorcingulate', 'ctx-lh-rostralmiddlefrontal', 'ctx-lh-superiorfrontal', 'ctx-lh-superiorparietal', 'ctx-lh-superiortemporal', 'ctx-lh-supramarginal', 'ctx-lh-transversetemporal', 'ctx-lh-insula', 'ctx-rh-unknown', 'ctx-rh-caudalanteriorcingulate', 'ctx-rh-caudalmiddlefrontal', 'ctx-rh-cuneus', 'ctx-rh-entorhinal', 'ctx-rh-fusiform', 'ctx-rh-inferiorparietal', 'ctx-rh-inferiortemporal', 'ctx-rh-isthmuscingulate', 'ctx-rh-lateraloccipital', 'ctx-rh-lateralorbitofrontal', 'ctx-rh-lingual', 'ctx-rh-medialorbitofrontal', 'ctx-rh-middletemporal', 'ctx-rh-parahippocampal', 'ctx-rh-paracentral', 'ctx-rh-parsopercularis', 'ctx-rh-parsorbitalis', 'ctx-rh-parstriangularis', 'ctx-rh-pericalcarine', 'ctx-rh-postcentral', 'ctx-rh-posteriorcingulate', 'ctx-rh-precentral', 'ctx-rh-precuneus', 'ctx-rh-rostralanteriorcingulate', 'ctx-rh-rostralmiddlefrontal', 'ctx-rh-superiorfrontal', 'ctx-rh-superiorparietal', 'ctx-rh-superiortemporal', 'ctx-rh-supramarginal', 'ctx-rh-transversetemporal', 'ctx-rh-insula']
# labels:  105
# [NiftiLabelsMasker.wrapped] loading data from /workspace/home/datasets/mri/schizo_datasets/COBRE/COBRE_freesurfer/A00016197/mri/aparc.DKTatlas+aseg.nii
# [Memory]0.1s, 0.0min    : Loading _filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# (150, 105)
# (105, 105)
# /workspace/home/datasets/mri/schizo_datasets/COBRE/COBRE_fmriprep/sub-A00006754/func/sub-A00006754_task-rest_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# start
# extraction:
# (256, 256, 256)
# ['Left-Cerebral-White-Matter', 'Left-Lateral-Ventricle', 'Left-Inf-Lat-Vent', 'Left-Cerebellum-White-Matter', 'Left-Cerebellum-Cortex', 'Left-Thalamus-Proper*', 'Left-Caudate', 'Left-Putamen', 'Left-Pallidum', '3rd-Ventricle', '4th-Ventricle', 'Brain-Stem', 'Left-Hippocampus', 'Left-Amygdala', 'CSF', 'Left-Accumbens-area', 'Left-VentralDC', 'Left-vessel', 'Left-choroid-plexus', 'Right-Cerebral-White-Matter', 'Right-Lateral-Ventricle', 'Right-Inf-Lat-Vent', 'Right-Cerebellum-White-Matter', 'Right-Cerebellum-Cortex', 'Right-Thalamus-Proper*', 'Right-Caudate', 'Right-Putamen', 'Right-Pallidum', 'Right-Hippocampus', 'Right-Amygdala', 'Right-Accumbens-area', 'Right-VentralDC', 'Right-vessel', 'Right-choroid-plexus', 'WM-hypointensities', 'Optic-Chiasm', 'CC_Posterior', 'CC_Mid_Posterior', 'CC_Central', 'CC_Mid_Anterior', 'CC_Anterior', 'ctx-lh-unknown', 'ctx-lh-caudalanteriorcingulate', 'ctx-lh-caudalmiddlefrontal', 'ctx-lh-cuneus', 'ctx-lh-entorhinal', 'ctx-lh-fusiform', 'ctx-lh-inferiorparietal', 'ctx-lh-inferiortemporal', 'ctx-lh-isthmuscingulate', 'ctx-lh-lateraloccipital', 'ctx-lh-lateralorbitofrontal', 'ctx-lh-lingual', 'ctx-lh-medialorbitofrontal', 'ctx-lh-middletemporal', 'ctx-lh-parahippocampal', 'ctx-lh-paracentral', 'ctx-lh-parsopercularis', 'ctx-lh-parsorbitalis', 'ctx-lh-parstriangularis', 'ctx-lh-pericalcarine', 'ctx-lh-postcentral', 'ctx-lh-posteriorcingulate', 'ctx-lh-precentral', 'ctx-lh-precuneus', 'ctx-lh-rostralanteriorcingulate', 'ctx-lh-rostralmiddlefrontal', 'ctx-lh-superiorfrontal', 'ctx-lh-superiorparietal', 'ctx-lh-superiortemporal', 'ctx-lh-supramarginal', 'ctx-lh-transversetemporal', 'ctx-lh-insula', 'ctx-rh-unknown', 'ctx-rh-caudalanteriorcingulate', 'ctx-rh-caudalmiddlefrontal', 'ctx-rh-cuneus', 'ctx-rh-entorhinal', 'ctx-rh-fusiform', 'ctx-rh-inferiorparietal', 'ctx-rh-inferiortemporal', 'ctx-rh-isthmuscingulate', 'ctx-rh-lateraloccipital', 'ctx-rh-lateralorbitofrontal', 'ctx-rh-lingual', 'ctx-rh-medialorbitofrontal', 'ctx-rh-middletemporal', 'ctx-rh-parahippocampal', 'ctx-rh-paracentral', 'ctx-rh-parsopercularis', 'ctx-rh-parsorbitalis', 'ctx-rh-parstriangularis', 'ctx-rh-pericalcarine', 'ctx-rh-postcentral', 'ctx-rh-posteriorcingulate', 'ctx-rh-precentral', 'ctx-rh-precuneus', 'ctx-rh-rostralanteriorcingulate', 'ctx-rh-rostralmiddlefrontal', 'ctx-rh-superiorfrontal', 'ctx-rh-superiorparietal', 'ctx-rh-superiortemporal', 'ctx-rh-supramarginal', 'ctx-rh-transversetemporal', 'ctx-rh-insula']
# labels:  105
# [NiftiLabelsMasker.wrapped] loading data from /workspace/home/datasets/mri/schizo_datasets/COBRE/COBRE_freesurfer/A00006754/mri/aparc.DKTatlas+aseg.nii
# [Memory]0.1s, 0.0min    : Loading _filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# (150, 105)
# (105, 105)
# /workspace/home/datasets/mri/schizo_datasets/COBRE/COBRE_fmriprep/sub-A00022509/func/sub-A00022509_task-rest_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# start
# extraction:
# (256, 256, 256)
# ['Left-Cerebral-White-Matter', 'Left-Lateral-Ventricle', 'Left-Inf-Lat-Vent', 'Left-Cerebellum-White-Matter', 'Left-Cerebellum-Cortex', 'Left-Thalamus-Proper*', 'Left-Caudate', 'Left-Putamen', 'Left-Pallidum', '3rd-Ventricle', '4th-Ventricle', 'Brain-Stem', 'Left-Hippocampus', 'Left-Amygdala', 'CSF', 'Left-Accumbens-area', 'Left-VentralDC', 'Left-vessel', 'Left-choroid-plexus', 'Right-Cerebral-White-Matter', 'Right-Cerebral-Cortex', 'Right-Lateral-Ventricle', 'Right-Inf-Lat-Vent', 'Right-Cerebellum-White-Matter', 'Right-Cerebellum-Cortex', 'Right-Thalamus-Proper*', 'Right-Caudate', 'Right-Putamen', 'Right-Pallidum', 'Right-Hippocampus', 'Right-Amygdala', 'Right-Accumbens-area', 'Right-VentralDC', 'Right-vessel', 'Right-choroid-plexus', 'WM-hypointensities', 'Optic-Chiasm', 'CC_Posterior', 'CC_Mid_Posterior', 'CC_Central', 'CC_Mid_Anterior', 'CC_Anterior', 'ctx-lh-unknown', 'ctx-lh-caudalanteriorcingulate', 'ctx-lh-caudalmiddlefrontal', 'ctx-lh-cuneus', 'ctx-lh-entorhinal', 'ctx-lh-fusiform', 'ctx-lh-inferiorparietal', 'ctx-lh-inferiortemporal', 'ctx-lh-isthmuscingulate', 'ctx-lh-lateraloccipital', 'ctx-lh-lateralorbitofrontal', 'ctx-lh-lingual', 'ctx-lh-medialorbitofrontal', 'ctx-lh-middletemporal', 'ctx-lh-parahippocampal', 'ctx-lh-paracentral', 'ctx-lh-parsopercularis', 'ctx-lh-parsorbitalis', 'ctx-lh-parstriangularis', 'ctx-lh-pericalcarine', 'ctx-lh-postcentral', 'ctx-lh-posteriorcingulate', 'ctx-lh-precentral', 'ctx-lh-precuneus', 'ctx-lh-rostralanteriorcingulate', 'ctx-lh-rostralmiddlefrontal', 'ctx-lh-superiorfrontal', 'ctx-lh-superiorparietal', 'ctx-lh-superiortemporal', 'ctx-lh-supramarginal', 'ctx-lh-transversetemporal', 'ctx-lh-insula', 'ctx-rh-unknown', 'ctx-rh-caudalanteriorcingulate', 'ctx-rh-caudalmiddlefrontal', 'ctx-rh-cuneus', 'ctx-rh-entorhinal', 'ctx-rh-fusiform', 'ctx-rh-inferiorparietal', 'ctx-rh-inferiortemporal', 'ctx-rh-isthmuscingulate', 'ctx-rh-lateraloccipital', 'ctx-rh-lateralorbitofrontal', 'ctx-rh-lingual', 'ctx-rh-medialorbitofrontal', 'ctx-rh-middletemporal', 'ctx-rh-parahippocampal', 'ctx-rh-paracentral', 'ctx-rh-parsopercularis', 'ctx-rh-parsorbitalis', 'ctx-rh-parstriangularis', 'ctx-rh-pericalcarine', 'ctx-rh-postcentral', 'ctx-rh-posteriorcingulate', 'ctx-rh-precentral', 'ctx-rh-precuneus', 'ctx-rh-rostralanteriorcingulate', 'ctx-rh-rostralmiddlefrontal', 'ctx-rh-superiorfrontal', 'ctx-rh-superiorparietal', 'ctx-rh-superiortemporal', 'ctx-rh-supramarginal', 'ctx-rh-transversetemporal', 'ctx-rh-insula']
# labels:  106
# [NiftiLabelsMasker.wrapped] loading data from /workspace/home/datasets/mri/schizo_datasets/COBRE/COBRE_freesurfer/A00022509/mri/aparc.DKTatlas+aseg.nii
# [Memory]0.1s, 0.0min    : Loading _filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# (150, 106)
# (106, 106)
# /workspace/home/datasets/mri/schizo_datasets/COBRE/COBRE_fmriprep/sub-A00014590/func/sub-A00014590_task-rest_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# start
# extraction:
# (256, 256, 256)
# ['Left-Cerebral-White-Matter', 'Left-Cerebral-Cortex', 'Left-Lateral-Ventricle', 'Left-Inf-Lat-Vent', 'Left-Cerebellum-White-Matter', 'Left-Cerebellum-Cortex', 'Left-Thalamus-Proper*', 'Left-Caudate', 'Left-Putamen', 'Left-Pallidum', '3rd-Ventricle', '4th-Ventricle', 'Brain-Stem', 'Left-Hippocampus', 'Left-Amygdala', 'CSF', 'Left-Accumbens-area', 'Left-VentralDC', 'Left-vessel', 'Left-choroid-plexus', 'Right-Cerebral-White-Matter', 'Right-Cerebral-Cortex', 'Right-Lateral-Ventricle', 'Right-Inf-Lat-Vent', 'Right-Cerebellum-White-Matter', 'Right-Cerebellum-Cortex', 'Right-Thalamus-Proper*', 'Right-Caudate', 'Right-Putamen', 'Right-Pallidum', 'Right-Hippocampus', 'Right-Amygdala', 'Right-Accumbens-area', 'Right-VentralDC', 'Right-vessel', 'Right-choroid-plexus', 'WM-hypointensities', 'Optic-Chiasm', 'CC_Posterior', 'CC_Mid_Posterior', 'CC_Central', 'CC_Mid_Anterior', 'CC_Anterior', 'ctx-lh-unknown', 'ctx-lh-caudalanteriorcingulate', 'ctx-lh-caudalmiddlefrontal', 'ctx-lh-cuneus', 'ctx-lh-entorhinal', 'ctx-lh-fusiform', 'ctx-lh-inferiorparietal', 'ctx-lh-inferiortemporal', 'ctx-lh-isthmuscingulate', 'ctx-lh-lateraloccipital', 'ctx-lh-lateralorbitofrontal', 'ctx-lh-lingual', 'ctx-lh-medialorbitofrontal', 'ctx-lh-middletemporal', 'ctx-lh-parahippocampal', 'ctx-lh-paracentral', 'ctx-lh-parsopercularis', 'ctx-lh-parsorbitalis', 'ctx-lh-parstriangularis', 'ctx-lh-pericalcarine', 'ctx-lh-postcentral', 'ctx-lh-posteriorcingulate', 'ctx-lh-precentral', 'ctx-lh-precuneus', 'ctx-lh-rostralanteriorcingulate', 'ctx-lh-rostralmiddlefrontal', 'ctx-lh-superiorfrontal', 'ctx-lh-superiorparietal', 'ctx-lh-superiortemporal', 'ctx-lh-supramarginal', 'ctx-lh-transversetemporal', 'ctx-lh-insula', 'ctx-rh-unknown', 'ctx-rh-caudalanteriorcingulate', 'ctx-rh-caudalmiddlefrontal', 'ctx-rh-cuneus', 'ctx-rh-entorhinal', 'ctx-rh-fusiform', 'ctx-rh-inferiorparietal', 'ctx-rh-inferiortemporal', 'ctx-rh-isthmuscingulate', 'ctx-rh-lateraloccipital', 'ctx-rh-lateralorbitofrontal', 'ctx-rh-lingual', 'ctx-rh-medialorbitofrontal', 'ctx-rh-middletemporal', 'ctx-rh-parahippocampal', 'ctx-rh-paracentral', 'ctx-rh-parsopercularis', 'ctx-rh-parsorbitalis', 'ctx-rh-parstriangularis', 'ctx-rh-pericalcarine', 'ctx-rh-postcentral', 'ctx-rh-posteriorcingulate', 'ctx-rh-precentral', 'ctx-rh-precuneus', 'ctx-rh-rostralanteriorcingulate', 'ctx-rh-rostralmiddlefrontal', 'ctx-rh-superiorfrontal', 'ctx-rh-superiorparietal', 'ctx-rh-superiortemporal', 'ctx-rh-supramarginal', 'ctx-rh-transversetemporal', 'ctx-rh-insula']
# labels:  107
# [NiftiLabelsMasker.wrapped] loading data from /workspace/home/datasets/mri/schizo_datasets/COBRE/COBRE_freesurfer/A00014590/mri/aparc.DKTatlas+aseg.nii
# [Memory]0.1s, 0.0min    : Loading _filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# (150, 107)
# (107, 107)
# /workspace/home/datasets/mri/schizo_datasets/COBRE/COBRE_fmriprep/sub-A00022400/func/sub-A00022400_task-rest_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# start
# extraction:
# (256, 256, 256)
# ['Left-Cerebral-White-Matter', 'Left-Lateral-Ventricle', 'Left-Inf-Lat-Vent', 'Left-Cerebellum-White-Matter', 'Left-Cerebellum-Cortex', 'Left-Thalamus-Proper*', 'Left-Caudate', 'Left-Putamen', 'Left-Pallidum', '3rd-Ventricle', '4th-Ventricle', 'Brain-Stem', 'Left-Hippocampus', 'Left-Amygdala', 'CSF', 'Left-Accumbens-area', 'Left-VentralDC', 'Left-vessel', 'Left-choroid-plexus', 'Right-Cerebral-White-Matter', 'Right-Cerebral-Cortex', 'Right-Lateral-Ventricle', 'Right-Inf-Lat-Vent', 'Right-Cerebellum-White-Matter', 'Right-Cerebellum-Cortex', 'Right-Thalamus-Proper*', 'Right-Caudate', 'Right-Putamen', 'Right-Pallidum', 'Right-Hippocampus', 'Right-Amygdala', 'Right-Accumbens-area', 'Right-VentralDC', 'Right-vessel', 'Right-choroid-plexus', 'WM-hypointensities', 'Optic-Chiasm', 'CC_Posterior', 'CC_Mid_Posterior', 'CC_Central', 'CC_Mid_Anterior', 'CC_Anterior', 'ctx-lh-unknown', 'ctx-lh-caudalanteriorcingulate', 'ctx-lh-caudalmiddlefrontal', 'ctx-lh-cuneus', 'ctx-lh-entorhinal', 'ctx-lh-fusiform', 'ctx-lh-inferiorparietal', 'ctx-lh-inferiortemporal', 'ctx-lh-isthmuscingulate', 'ctx-lh-lateraloccipital', 'ctx-lh-lateralorbitofrontal', 'ctx-lh-lingual', 'ctx-lh-medialorbitofrontal', 'ctx-lh-middletemporal', 'ctx-lh-parahippocampal', 'ctx-lh-paracentral', 'ctx-lh-parsopercularis', 'ctx-lh-parsorbitalis', 'ctx-lh-parstriangularis', 'ctx-lh-pericalcarine', 'ctx-lh-postcentral', 'ctx-lh-posteriorcingulate', 'ctx-lh-precentral', 'ctx-lh-precuneus', 'ctx-lh-rostralanteriorcingulate', 'ctx-lh-rostralmiddlefrontal', 'ctx-lh-superiorfrontal', 'ctx-lh-superiorparietal', 'ctx-lh-superiortemporal', 'ctx-lh-supramarginal', 'ctx-lh-transversetemporal', 'ctx-lh-insula', 'ctx-rh-unknown', 'ctx-rh-caudalanteriorcingulate', 'ctx-rh-caudalmiddlefrontal', 'ctx-rh-cuneus', 'ctx-rh-entorhinal', 'ctx-rh-fusiform', 'ctx-rh-inferiorparietal', 'ctx-rh-inferiortemporal', 'ctx-rh-isthmuscingulate', 'ctx-rh-lateraloccipital', 'ctx-rh-lateralorbitofrontal', 'ctx-rh-lingual', 'ctx-rh-medialorbitofrontal', 'ctx-rh-middletemporal', 'ctx-rh-parahippocampal', 'ctx-rh-paracentral', 'ctx-rh-parsopercularis', 'ctx-rh-parsorbitalis', 'ctx-rh-parstriangularis', 'ctx-rh-pericalcarine', 'ctx-rh-postcentral', 'ctx-rh-posteriorcingulate', 'ctx-rh-precentral', 'ctx-rh-precuneus', 'ctx-rh-rostralanteriorcingulate', 'ctx-rh-rostralmiddlefrontal', 'ctx-rh-superiorfrontal', 'ctx-rh-superiorparietal', 'ctx-rh-superiortemporal', 'ctx-rh-supramarginal', 'ctx-rh-transversetemporal', 'ctx-rh-insula']
# labels:  106
# [NiftiLabelsMasker.wrapped] loading data from /workspace/home/datasets/mri/schizo_datasets/COBRE/COBRE_freesurfer/A00022400/mri/aparc.DKTatlas+aseg.nii
# [Memory]0.1s, 0.0min    : Loading _filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# (150, 106)
# (106, 106)
# /workspace/home/datasets/mri/schizo_datasets/COBRE/COBRE_fmriprep/sub-A00022727/func/sub-A00022727_task-rest_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# start
# extraction:
# (256, 256, 256)
# ['Left-Cerebral-White-Matter', 'Left-Cerebral-Cortex', 'Left-Lateral-Ventricle', 'Left-Inf-Lat-Vent', 'Left-Cerebellum-White-Matter', 'Left-Cerebellum-Cortex', 'Left-Thalamus-Proper*', 'Left-Caudate', 'Left-Putamen', 'Left-Pallidum', '3rd-Ventricle', '4th-Ventricle', 'Brain-Stem', 'Left-Hippocampus', 'Left-Amygdala', 'CSF', 'Left-Accumbens-area', 'Left-VentralDC', 'Left-vessel', 'Left-choroid-plexus', 'Right-Cerebral-White-Matter', 'Right-Lateral-Ventricle', 'Right-Inf-Lat-Vent', 'Right-Cerebellum-White-Matter', 'Right-Cerebellum-Cortex', 'Right-Thalamus-Proper*', 'Right-Caudate', 'Right-Putamen', 'Right-Pallidum', 'Right-Hippocampus', 'Right-Amygdala', 'Right-Accumbens-area', 'Right-VentralDC', 'Right-vessel', 'Right-choroid-plexus', 'WM-hypointensities', 'Optic-Chiasm', 'CC_Posterior', 'CC_Mid_Posterior', 'CC_Central', 'CC_Mid_Anterior', 'CC_Anterior', 'ctx-lh-unknown', 'ctx-lh-caudalanteriorcingulate', 'ctx-lh-caudalmiddlefrontal', 'ctx-lh-cuneus', 'ctx-lh-entorhinal', 'ctx-lh-fusiform', 'ctx-lh-inferiorparietal', 'ctx-lh-inferiortemporal', 'ctx-lh-isthmuscingulate', 'ctx-lh-lateraloccipital', 'ctx-lh-lateralorbitofrontal', 'ctx-lh-lingual', 'ctx-lh-medialorbitofrontal', 'ctx-lh-middletemporal', 'ctx-lh-parahippocampal', 'ctx-lh-paracentral', 'ctx-lh-parsopercularis', 'ctx-lh-parsorbitalis', 'ctx-lh-parstriangularis', 'ctx-lh-pericalcarine', 'ctx-lh-postcentral', 'ctx-lh-posteriorcingulate', 'ctx-lh-precentral', 'ctx-lh-precuneus', 'ctx-lh-rostralanteriorcingulate', 'ctx-lh-rostralmiddlefrontal', 'ctx-lh-superiorfrontal', 'ctx-lh-superiorparietal', 'ctx-lh-superiortemporal', 'ctx-lh-supramarginal', 'ctx-lh-transversetemporal', 'ctx-lh-insula', 'ctx-rh-unknown', 'ctx-rh-caudalanteriorcingulate', 'ctx-rh-caudalmiddlefrontal', 'ctx-rh-cuneus', 'ctx-rh-entorhinal', 'ctx-rh-fusiform', 'ctx-rh-inferiorparietal', 'ctx-rh-inferiortemporal', 'ctx-rh-isthmuscingulate', 'ctx-rh-lateraloccipital', 'ctx-rh-lateralorbitofrontal', 'ctx-rh-lingual', 'ctx-rh-medialorbitofrontal', 'ctx-rh-middletemporal', 'ctx-rh-parahippocampal', 'ctx-rh-paracentral', 'ctx-rh-parsopercularis', 'ctx-rh-parsorbitalis', 'ctx-rh-parstriangularis', 'ctx-rh-pericalcarine', 'ctx-rh-postcentral', 'ctx-rh-posteriorcingulate', 'ctx-rh-precentral', 'ctx-rh-precuneus', 'ctx-rh-rostralanteriorcingulate', 'ctx-rh-rostralmiddlefrontal', 'ctx-rh-superiorfrontal', 'ctx-rh-superiorparietal', 'ctx-rh-superiortemporal', 'ctx-rh-supramarginal', 'ctx-rh-transversetemporal', 'ctx-rh-insula']
# labels:  106
# [NiftiLabelsMasker.wrapped] loading data from /workspace/home/datasets/mri/schizo_datasets/COBRE/COBRE_freesurfer/A00022727/mri/aparc.DKTatlas+aseg.nii
# [Memory]0.1s, 0.0min    : Loading _filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# (150, 106)
# (106, 106)
# /workspace/home/datasets/mri/schizo_datasets/COBRE/COBRE_fmriprep/sub-A00001251/func/sub-A00001251_task-rest_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# start
# extraction:
# (256, 256, 256)
# ['Left-Cerebral-White-Matter', 'Left-Lateral-Ventricle', 'Left-Inf-Lat-Vent', 'Left-Cerebellum-White-Matter', 'Left-Cerebellum-Cortex', 'Left-Thalamus-Proper*', 'Left-Caudate', 'Left-Putamen', 'Left-Pallidum', '3rd-Ventricle', '4th-Ventricle', 'Brain-Stem', 'Left-Hippocampus', 'Left-Amygdala', 'CSF', 'Left-Accumbens-area', 'Left-VentralDC', 'Left-vessel', 'Left-choroid-plexus', 'Right-Cerebral-White-Matter', 'Right-Lateral-Ventricle', 'Right-Inf-Lat-Vent', 'Right-Cerebellum-White-Matter', 'Right-Cerebellum-Cortex', 'Right-Thalamus-Proper*', 'Right-Caudate', 'Right-Putamen', 'Right-Pallidum', 'Right-Hippocampus', 'Right-Amygdala', 'Right-Accumbens-area', 'Right-VentralDC', 'Right-vessel', 'Right-choroid-plexus', 'WM-hypointensities', 'Optic-Chiasm', 'CC_Posterior', 'CC_Mid_Posterior', 'CC_Central', 'CC_Mid_Anterior', 'CC_Anterior', 'ctx-lh-unknown', 'ctx-lh-caudalanteriorcingulate', 'ctx-lh-caudalmiddlefrontal', 'ctx-lh-cuneus', 'ctx-lh-entorhinal', 'ctx-lh-fusiform', 'ctx-lh-inferiorparietal', 'ctx-lh-inferiortemporal', 'ctx-lh-isthmuscingulate', 'ctx-lh-lateraloccipital', 'ctx-lh-lateralorbitofrontal', 'ctx-lh-lingual', 'ctx-lh-medialorbitofrontal', 'ctx-lh-middletemporal', 'ctx-lh-parahippocampal', 'ctx-lh-paracentral', 'ctx-lh-parsopercularis', 'ctx-lh-parsorbitalis', 'ctx-lh-parstriangularis', 'ctx-lh-pericalcarine', 'ctx-lh-postcentral', 'ctx-lh-posteriorcingulate', 'ctx-lh-precentral', 'ctx-lh-precuneus', 'ctx-lh-rostralanteriorcingulate', 'ctx-lh-rostralmiddlefrontal', 'ctx-lh-superiorfrontal', 'ctx-lh-superiorparietal', 'ctx-lh-superiortemporal', 'ctx-lh-supramarginal', 'ctx-lh-transversetemporal', 'ctx-lh-insula', 'ctx-rh-unknown', 'ctx-rh-caudalanteriorcingulate', 'ctx-rh-caudalmiddlefrontal', 'ctx-rh-cuneus', 'ctx-rh-entorhinal', 'ctx-rh-fusiform', 'ctx-rh-inferiorparietal', 'ctx-rh-inferiortemporal', 'ctx-rh-isthmuscingulate', 'ctx-rh-lateraloccipital', 'ctx-rh-lateralorbitofrontal', 'ctx-rh-lingual', 'ctx-rh-medialorbitofrontal', 'ctx-rh-middletemporal', 'ctx-rh-parahippocampal', 'ctx-rh-paracentral', 'ctx-rh-parsopercularis', 'ctx-rh-parsorbitalis', 'ctx-rh-parstriangularis', 'ctx-rh-pericalcarine', 'ctx-rh-postcentral', 'ctx-rh-posteriorcingulate', 'ctx-rh-precentral', 'ctx-rh-precuneus', 'ctx-rh-rostralanteriorcingulate', 'ctx-rh-rostralmiddlefrontal', 'ctx-rh-superiorfrontal', 'ctx-rh-superiorparietal', 'ctx-rh-superiortemporal', 'ctx-rh-supramarginal', 'ctx-rh-transversetemporal', 'ctx-rh-insula']
# labels:  105
# [NiftiLabelsMasker.wrapped] loading data from /workspace/home/datasets/mri/schizo_datasets/COBRE/COBRE_freesurfer/A00001251/mri/aparc.DKTatlas+aseg.nii
# [Memory]0.1s, 0.0min    : Loading _filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# (150, 105)
# (105, 105)
# /workspace/home/datasets/mri/schizo_datasets/COBRE/COBRE_fmriprep/sub-A00018317/func/sub-A00018317_task-rest_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# start
# extraction:
# (256, 256, 256)
# ['Left-Cerebral-White-Matter', 'Left-Lateral-Ventricle', 'Left-Inf-Lat-Vent', 'Left-Cerebellum-White-Matter', 'Left-Cerebellum-Cortex', 'Left-Thalamus-Proper*', 'Left-Caudate', 'Left-Putamen', 'Left-Pallidum', '3rd-Ventricle', '4th-Ventricle', 'Brain-Stem', 'Left-Hippocampus', 'Left-Amygdala', 'CSF', 'Left-Accumbens-area', 'Left-VentralDC', 'Left-vessel', 'Left-choroid-plexus', 'Right-Cerebral-White-Matter', 'Right-Lateral-Ventricle', 'Right-Inf-Lat-Vent', 'Right-Cerebellum-White-Matter', 'Right-Cerebellum-Cortex', 'Right-Thalamus-Proper*', 'Right-Caudate', 'Right-Putamen', 'Right-Pallidum', 'Right-Hippocampus', 'Right-Amygdala', 'Right-Accumbens-area', 'Right-VentralDC', 'Right-vessel', 'Right-choroid-plexus', 'WM-hypointensities', 'Optic-Chiasm', 'CC_Posterior', 'CC_Mid_Posterior', 'CC_Central', 'CC_Mid_Anterior', 'CC_Anterior', 'ctx-lh-unknown', 'ctx-lh-caudalanteriorcingulate', 'ctx-lh-caudalmiddlefrontal', 'ctx-lh-cuneus', 'ctx-lh-entorhinal', 'ctx-lh-fusiform', 'ctx-lh-inferiorparietal', 'ctx-lh-inferiortemporal', 'ctx-lh-isthmuscingulate', 'ctx-lh-lateraloccipital', 'ctx-lh-lateralorbitofrontal', 'ctx-lh-lingual', 'ctx-lh-medialorbitofrontal', 'ctx-lh-middletemporal', 'ctx-lh-parahippocampal', 'ctx-lh-paracentral', 'ctx-lh-parsopercularis', 'ctx-lh-parsorbitalis', 'ctx-lh-parstriangularis', 'ctx-lh-pericalcarine', 'ctx-lh-postcentral', 'ctx-lh-posteriorcingulate', 'ctx-lh-precentral', 'ctx-lh-precuneus', 'ctx-lh-rostralanteriorcingulate', 'ctx-lh-rostralmiddlefrontal', 'ctx-lh-superiorfrontal', 'ctx-lh-superiorparietal', 'ctx-lh-superiortemporal', 'ctx-lh-supramarginal', 'ctx-lh-transversetemporal', 'ctx-lh-insula', 'ctx-rh-unknown', 'ctx-rh-caudalanteriorcingulate', 'ctx-rh-caudalmiddlefrontal', 'ctx-rh-cuneus', 'ctx-rh-entorhinal', 'ctx-rh-fusiform', 'ctx-rh-inferiorparietal', 'ctx-rh-inferiortemporal', 'ctx-rh-isthmuscingulate', 'ctx-rh-lateraloccipital', 'ctx-rh-lateralorbitofrontal', 'ctx-rh-lingual', 'ctx-rh-medialorbitofrontal', 'ctx-rh-middletemporal', 'ctx-rh-parahippocampal', 'ctx-rh-paracentral', 'ctx-rh-parsopercularis', 'ctx-rh-parsorbitalis', 'ctx-rh-parstriangularis', 'ctx-rh-pericalcarine', 'ctx-rh-postcentral', 'ctx-rh-posteriorcingulate', 'ctx-rh-precentral', 'ctx-rh-precuneus', 'ctx-rh-rostralanteriorcingulate', 'ctx-rh-rostralmiddlefrontal', 'ctx-rh-superiorfrontal', 'ctx-rh-superiorparietal', 'ctx-rh-superiortemporal', 'ctx-rh-supramarginal', 'ctx-rh-transversetemporal', 'ctx-rh-insula']
# labels:  105
# [NiftiLabelsMasker.wrapped] loading data from /workspace/home/datasets/mri/schizo_datasets/COBRE/COBRE_freesurfer/A00018317/mri/aparc.DKTatlas+aseg.nii
# [Memory]0.1s, 0.0min    : Loading _filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# (150, 105)
# (105, 105)
# /workspace/home/datasets/mri/schizo_datasets/COBRE/COBRE_fmriprep/sub-A00017147/func/sub-A00017147_task-rest_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# start
# extraction:
# (256, 256, 256)
# ['Left-Cerebral-White-Matter', 'Left-Lateral-Ventricle', 'Left-Inf-Lat-Vent', 'Left-Cerebellum-White-Matter', 'Left-Cerebellum-Cortex', 'Left-Thalamus-Proper*', 'Left-Caudate', 'Left-Putamen', 'Left-Pallidum', '3rd-Ventricle', '4th-Ventricle', 'Brain-Stem', 'Left-Hippocampus', 'Left-Amygdala', 'CSF', 'Left-Accumbens-area', 'Left-VentralDC', 'Left-vessel', 'Left-choroid-plexus', 'Right-Cerebral-White-Matter', 'Right-Cerebral-Cortex', 'Right-Lateral-Ventricle', 'Right-Inf-Lat-Vent', 'Right-Cerebellum-White-Matter', 'Right-Cerebellum-Cortex', 'Right-Thalamus-Proper*', 'Right-Caudate', 'Right-Putamen', 'Right-Pallidum', 'Right-Hippocampus', 'Right-Amygdala', 'Right-Accumbens-area', 'Right-VentralDC', 'Right-vessel', 'Right-choroid-plexus', '5th-Ventricle', 'WM-hypointensities', 'Optic-Chiasm', 'CC_Posterior', 'CC_Mid_Posterior', 'CC_Central', 'CC_Mid_Anterior', 'CC_Anterior', 'ctx-lh-unknown', 'ctx-lh-caudalanteriorcingulate', 'ctx-lh-caudalmiddlefrontal', 'ctx-lh-cuneus', 'ctx-lh-entorhinal', 'ctx-lh-fusiform', 'ctx-lh-inferiorparietal', 'ctx-lh-inferiortemporal', 'ctx-lh-isthmuscingulate', 'ctx-lh-lateraloccipital', 'ctx-lh-lateralorbitofrontal', 'ctx-lh-lingual', 'ctx-lh-medialorbitofrontal', 'ctx-lh-middletemporal', 'ctx-lh-parahippocampal', 'ctx-lh-paracentral', 'ctx-lh-parsopercularis', 'ctx-lh-parsorbitalis', 'ctx-lh-parstriangularis', 'ctx-lh-pericalcarine', 'ctx-lh-postcentral', 'ctx-lh-posteriorcingulate', 'ctx-lh-precentral', 'ctx-lh-precuneus', 'ctx-lh-rostralanteriorcingulate', 'ctx-lh-rostralmiddlefrontal', 'ctx-lh-superiorfrontal', 'ctx-lh-superiorparietal', 'ctx-lh-superiortemporal', 'ctx-lh-supramarginal', 'ctx-lh-transversetemporal', 'ctx-lh-insula', 'ctx-rh-unknown', 'ctx-rh-caudalanteriorcingulate', 'ctx-rh-caudalmiddlefrontal', 'ctx-rh-cuneus', 'ctx-rh-entorhinal', 'ctx-rh-fusiform', 'ctx-rh-inferiorparietal', 'ctx-rh-inferiortemporal', 'ctx-rh-isthmuscingulate', 'ctx-rh-lateraloccipital', 'ctx-rh-lateralorbitofrontal', 'ctx-rh-lingual', 'ctx-rh-medialorbitofrontal', 'ctx-rh-middletemporal', 'ctx-rh-parahippocampal', 'ctx-rh-paracentral', 'ctx-rh-parsopercularis', 'ctx-rh-parsorbitalis', 'ctx-rh-parstriangularis', 'ctx-rh-pericalcarine', 'ctx-rh-postcentral', 'ctx-rh-posteriorcingulate', 'ctx-rh-precentral', 'ctx-rh-precuneus', 'ctx-rh-rostralanteriorcingulate', 'ctx-rh-rostralmiddlefrontal', 'ctx-rh-superiorfrontal', 'ctx-rh-superiorparietal', 'ctx-rh-superiortemporal', 'ctx-rh-supramarginal', 'ctx-rh-transversetemporal', 'ctx-rh-insula']
# labels:  107
# [NiftiLabelsMasker.wrapped] loading data from /workspace/home/datasets/mri/schizo_datasets/COBRE/COBRE_freesurfer/A00017147/mri/aparc.DKTatlas+aseg.nii
# [Memory]0.1s, 0.0min    : Loading _filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# (150, 107)
# (107, 107)
# /workspace/home/datasets/mri/schizo_datasets/COBRE/COBRE_fmriprep/sub-A00013816/func/sub-A00013816_task-rest_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# start
# extraction:
# (256, 256, 256)
# ['Left-Cerebral-White-Matter', 'Left-Cerebral-Cortex', 'Left-Lateral-Ventricle', 'Left-Inf-Lat-Vent', 'Left-Cerebellum-White-Matter', 'Left-Cerebellum-Cortex', 'Left-Thalamus-Proper*', 'Left-Caudate', 'Left-Putamen', 'Left-Pallidum', '3rd-Ventricle', '4th-Ventricle', 'Brain-Stem', 'Left-Hippocampus', 'Left-Amygdala', 'CSF', 'Left-Accumbens-area', 'Left-VentralDC', 'Left-vessel', 'Left-choroid-plexus', 'Right-Cerebral-White-Matter', 'Right-Cerebral-Cortex', 'Right-Lateral-Ventricle', 'Right-Inf-Lat-Vent', 'Right-Cerebellum-White-Matter', 'Right-Cerebellum-Cortex', 'Right-Thalamus-Proper*', 'Right-Caudate', 'Right-Putamen', 'Right-Pallidum', 'Right-Hippocampus', 'Right-Amygdala', 'Right-Accumbens-area', 'Right-VentralDC', 'Right-vessel', 'Right-choroid-plexus', 'WM-hypointensities', 'Optic-Chiasm', 'CC_Posterior', 'CC_Mid_Posterior', 'CC_Central', 'CC_Mid_Anterior', 'CC_Anterior', 'ctx-lh-unknown', 'ctx-lh-caudalanteriorcingulate', 'ctx-lh-caudalmiddlefrontal', 'ctx-lh-cuneus', 'ctx-lh-entorhinal', 'ctx-lh-fusiform', 'ctx-lh-inferiorparietal', 'ctx-lh-inferiortemporal', 'ctx-lh-isthmuscingulate', 'ctx-lh-lateraloccipital', 'ctx-lh-lateralorbitofrontal', 'ctx-lh-lingual', 'ctx-lh-medialorbitofrontal', 'ctx-lh-middletemporal', 'ctx-lh-parahippocampal', 'ctx-lh-paracentral', 'ctx-lh-parsopercularis', 'ctx-lh-parsorbitalis', 'ctx-lh-parstriangularis', 'ctx-lh-pericalcarine', 'ctx-lh-postcentral', 'ctx-lh-posteriorcingulate', 'ctx-lh-precentral', 'ctx-lh-precuneus', 'ctx-lh-rostralanteriorcingulate', 'ctx-lh-rostralmiddlefrontal', 'ctx-lh-superiorfrontal', 'ctx-lh-superiorparietal', 'ctx-lh-superiortemporal', 'ctx-lh-supramarginal', 'ctx-lh-transversetemporal', 'ctx-lh-insula', 'ctx-rh-unknown', 'ctx-rh-caudalanteriorcingulate', 'ctx-rh-caudalmiddlefrontal', 'ctx-rh-cuneus', 'ctx-rh-entorhinal', 'ctx-rh-fusiform', 'ctx-rh-inferiorparietal', 'ctx-rh-inferiortemporal', 'ctx-rh-isthmuscingulate', 'ctx-rh-lateraloccipital', 'ctx-rh-lateralorbitofrontal', 'ctx-rh-lingual', 'ctx-rh-medialorbitofrontal', 'ctx-rh-middletemporal', 'ctx-rh-parahippocampal', 'ctx-rh-paracentral', 'ctx-rh-parsopercularis', 'ctx-rh-parsorbitalis', 'ctx-rh-parstriangularis', 'ctx-rh-pericalcarine', 'ctx-rh-postcentral', 'ctx-rh-posteriorcingulate', 'ctx-rh-precentral', 'ctx-rh-precuneus', 'ctx-rh-rostralanteriorcingulate', 'ctx-rh-rostralmiddlefrontal', 'ctx-rh-superiorfrontal', 'ctx-rh-superiorparietal', 'ctx-rh-superiortemporal', 'ctx-rh-supramarginal', 'ctx-rh-transversetemporal', 'ctx-rh-insula']
# labels:  107
# [NiftiLabelsMasker.wrapped] loading data from /workspace/home/datasets/mri/schizo_datasets/COBRE/COBRE_freesurfer/A00013816/mri/aparc.DKTatlas+aseg.nii
# [Memory]0.1s, 0.0min    : Loading _filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# (150, 107)
# (107, 107)
# /workspace/home/datasets/mri/schizo_datasets/COBRE/COBRE_fmriprep/sub-A00015759/func/sub-A00015759_task-rest_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# start
# extraction:
# (256, 256, 256)
# ['Left-Cerebral-White-Matter', 'Left-Cerebral-Cortex', 'Left-Lateral-Ventricle', 'Left-Inf-Lat-Vent', 'Left-Cerebellum-White-Matter', 'Left-Cerebellum-Cortex', 'Left-Thalamus-Proper*', 'Left-Caudate', 'Left-Putamen', 'Left-Pallidum', '3rd-Ventricle', '4th-Ventricle', 'Brain-Stem', 'Left-Hippocampus', 'Left-Amygdala', 'CSF', 'Left-Accumbens-area', 'Left-VentralDC', 'Left-vessel', 'Left-choroid-plexus', 'Right-Cerebral-White-Matter', 'Right-Cerebral-Cortex', 'Right-Lateral-Ventricle', 'Right-Inf-Lat-Vent', 'Right-Cerebellum-White-Matter', 'Right-Cerebellum-Cortex', 'Right-Thalamus-Proper*', 'Right-Caudate', 'Right-Putamen', 'Right-Pallidum', 'Right-Hippocampus', 'Right-Amygdala', 'Right-Accumbens-area', 'Right-VentralDC', 'Right-vessel', 'Right-choroid-plexus', 'WM-hypointensities', 'Optic-Chiasm', 'CC_Posterior', 'CC_Mid_Posterior', 'CC_Central', 'CC_Mid_Anterior', 'CC_Anterior', 'ctx-lh-unknown', 'ctx-lh-caudalanteriorcingulate', 'ctx-lh-caudalmiddlefrontal', 'ctx-lh-cuneus', 'ctx-lh-entorhinal', 'ctx-lh-fusiform', 'ctx-lh-inferiorparietal', 'ctx-lh-inferiortemporal', 'ctx-lh-isthmuscingulate', 'ctx-lh-lateraloccipital', 'ctx-lh-lateralorbitofrontal', 'ctx-lh-lingual', 'ctx-lh-medialorbitofrontal', 'ctx-lh-middletemporal', 'ctx-lh-parahippocampal', 'ctx-lh-paracentral', 'ctx-lh-parsopercularis', 'ctx-lh-parsorbitalis', 'ctx-lh-parstriangularis', 'ctx-lh-pericalcarine', 'ctx-lh-postcentral', 'ctx-lh-posteriorcingulate', 'ctx-lh-precentral', 'ctx-lh-precuneus', 'ctx-lh-rostralanteriorcingulate', 'ctx-lh-rostralmiddlefrontal', 'ctx-lh-superiorfrontal', 'ctx-lh-superiorparietal', 'ctx-lh-superiortemporal', 'ctx-lh-supramarginal', 'ctx-lh-transversetemporal', 'ctx-lh-insula', 'ctx-rh-unknown', 'ctx-rh-caudalanteriorcingulate', 'ctx-rh-caudalmiddlefrontal', 'ctx-rh-cuneus', 'ctx-rh-entorhinal', 'ctx-rh-fusiform', 'ctx-rh-inferiorparietal', 'ctx-rh-inferiortemporal', 'ctx-rh-isthmuscingulate', 'ctx-rh-lateraloccipital', 'ctx-rh-lateralorbitofrontal', 'ctx-rh-lingual', 'ctx-rh-medialorbitofrontal', 'ctx-rh-middletemporal', 'ctx-rh-parahippocampal', 'ctx-rh-paracentral', 'ctx-rh-parsopercularis', 'ctx-rh-parsorbitalis', 'ctx-rh-parstriangularis', 'ctx-rh-pericalcarine', 'ctx-rh-postcentral', 'ctx-rh-posteriorcingulate', 'ctx-rh-precentral', 'ctx-rh-precuneus', 'ctx-rh-rostralanteriorcingulate', 'ctx-rh-rostralmiddlefrontal', 'ctx-rh-superiorfrontal', 'ctx-rh-superiorparietal', 'ctx-rh-superiortemporal', 'ctx-rh-supramarginal', 'ctx-rh-transversetemporal', 'ctx-rh-insula']
# labels:  107
# [NiftiLabelsMasker.wrapped] loading data from /workspace/home/datasets/mri/schizo_datasets/COBRE/COBRE_freesurfer/A00015759/mri/aparc.DKTatlas+aseg.nii
# [Memory]0.1s, 0.0min    : Loading _filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# (150, 107)
# (107, 107)
# /workspace/home/datasets/mri/schizo_datasets/COBRE/COBRE_fmriprep/sub-A00021598/func/sub-A00021598_task-rest_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# start
# extraction:
# (256, 256, 256)
# ['Left-Cerebral-White-Matter', 'Left-Cerebral-Cortex', 'Left-Lateral-Ventricle', 'Left-Inf-Lat-Vent', 'Left-Cerebellum-White-Matter', 'Left-Cerebellum-Cortex', 'Left-Thalamus-Proper*', 'Left-Caudate', 'Left-Putamen', 'Left-Pallidum', '3rd-Ventricle', '4th-Ventricle', 'Brain-Stem', 'Left-Hippocampus', 'Left-Amygdala', 'CSF', 'Left-Accumbens-area', 'Left-VentralDC', 'Left-vessel', 'Left-choroid-plexus', 'Right-Cerebral-White-Matter', 'Right-Cerebral-Cortex', 'Right-Lateral-Ventricle', 'Right-Inf-Lat-Vent', 'Right-Cerebellum-White-Matter', 'Right-Cerebellum-Cortex', 'Right-Thalamus-Proper*', 'Right-Caudate', 'Right-Putamen', 'Right-Pallidum', 'Right-Hippocampus', 'Right-Amygdala', 'Right-Accumbens-area', 'Right-VentralDC', 'Right-vessel', 'Right-choroid-plexus', 'WM-hypointensities', 'Optic-Chiasm', 'CC_Posterior', 'CC_Mid_Posterior', 'CC_Central', 'CC_Mid_Anterior', 'CC_Anterior', 'ctx-lh-unknown', 'ctx-lh-caudalanteriorcingulate', 'ctx-lh-caudalmiddlefrontal', 'ctx-lh-cuneus', 'ctx-lh-entorhinal', 'ctx-lh-fusiform', 'ctx-lh-inferiorparietal', 'ctx-lh-inferiortemporal', 'ctx-lh-isthmuscingulate', 'ctx-lh-lateraloccipital', 'ctx-lh-lateralorbitofrontal', 'ctx-lh-lingual', 'ctx-lh-medialorbitofrontal', 'ctx-lh-middletemporal', 'ctx-lh-parahippocampal', 'ctx-lh-paracentral', 'ctx-lh-parsopercularis', 'ctx-lh-parsorbitalis', 'ctx-lh-parstriangularis', 'ctx-lh-pericalcarine', 'ctx-lh-postcentral', 'ctx-lh-posteriorcingulate', 'ctx-lh-precentral', 'ctx-lh-precuneus', 'ctx-lh-rostralanteriorcingulate', 'ctx-lh-rostralmiddlefrontal', 'ctx-lh-superiorfrontal', 'ctx-lh-superiorparietal', 'ctx-lh-superiortemporal', 'ctx-lh-supramarginal', 'ctx-lh-transversetemporal', 'ctx-lh-insula', 'ctx-rh-unknown', 'ctx-rh-caudalanteriorcingulate', 'ctx-rh-caudalmiddlefrontal', 'ctx-rh-cuneus', 'ctx-rh-entorhinal', 'ctx-rh-fusiform', 'ctx-rh-inferiorparietal', 'ctx-rh-inferiortemporal', 'ctx-rh-isthmuscingulate', 'ctx-rh-lateraloccipital', 'ctx-rh-lateralorbitofrontal', 'ctx-rh-lingual', 'ctx-rh-medialorbitofrontal', 'ctx-rh-middletemporal', 'ctx-rh-parahippocampal', 'ctx-rh-paracentral', 'ctx-rh-parsopercularis', 'ctx-rh-parsorbitalis', 'ctx-rh-parstriangularis', 'ctx-rh-pericalcarine', 'ctx-rh-postcentral', 'ctx-rh-posteriorcingulate', 'ctx-rh-precentral', 'ctx-rh-precuneus', 'ctx-rh-rostralanteriorcingulate', 'ctx-rh-rostralmiddlefrontal', 'ctx-rh-superiorfrontal', 'ctx-rh-superiorparietal', 'ctx-rh-superiortemporal', 'ctx-rh-supramarginal', 'ctx-rh-transversetemporal', 'ctx-rh-insula']
# labels:  107
# [NiftiLabelsMasker.wrapped] loading data from /workspace/home/datasets/mri/schizo_datasets/COBRE/COBRE_freesurfer/A00021598/mri/aparc.DKTatlas+aseg.nii
# [Memory]0.1s, 0.0min    : Loading _filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# (150, 107)
# (107, 107)
# /workspace/home/datasets/mri/schizo_datasets/COBRE/COBRE_fmriprep/sub-A00027787/func/sub-A00027787_task-rest_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# start
# extraction:
# (256, 256, 256)
# ['Left-Cerebral-White-Matter', 'Left-Cerebral-Cortex', 'Left-Lateral-Ventricle', 'Left-Inf-Lat-Vent', 'Left-Cerebellum-White-Matter', 'Left-Cerebellum-Cortex', 'Left-Thalamus-Proper*', 'Left-Caudate', 'Left-Putamen', 'Left-Pallidum', '3rd-Ventricle', '4th-Ventricle', 'Brain-Stem', 'Left-Hippocampus', 'Left-Amygdala', 'CSF', 'Left-Accumbens-area', 'Left-VentralDC', 'Left-vessel', 'Left-choroid-plexus', 'Right-Cerebral-White-Matter', 'Right-Cerebral-Cortex', 'Right-Lateral-Ventricle', 'Right-Inf-Lat-Vent', 'Right-Cerebellum-White-Matter', 'Right-Cerebellum-Cortex', 'Right-Thalamus-Proper*', 'Right-Caudate', 'Right-Putamen', 'Right-Pallidum', 'Right-Hippocampus', 'Right-Amygdala', 'Right-Accumbens-area', 'Right-VentralDC', 'Right-vessel', 'Right-choroid-plexus', 'WM-hypointensities', 'Optic-Chiasm', 'CC_Posterior', 'CC_Mid_Posterior', 'CC_Central', 'CC_Mid_Anterior', 'CC_Anterior', 'ctx-lh-unknown', 'ctx-lh-caudalanteriorcingulate', 'ctx-lh-caudalmiddlefrontal', 'ctx-lh-cuneus', 'ctx-lh-entorhinal', 'ctx-lh-fusiform', 'ctx-lh-inferiorparietal', 'ctx-lh-inferiortemporal', 'ctx-lh-isthmuscingulate', 'ctx-lh-lateraloccipital', 'ctx-lh-lateralorbitofrontal', 'ctx-lh-lingual', 'ctx-lh-medialorbitofrontal', 'ctx-lh-middletemporal', 'ctx-lh-parahippocampal', 'ctx-lh-paracentral', 'ctx-lh-parsopercularis', 'ctx-lh-parsorbitalis', 'ctx-lh-parstriangularis', 'ctx-lh-pericalcarine', 'ctx-lh-postcentral', 'ctx-lh-posteriorcingulate', 'ctx-lh-precentral', 'ctx-lh-precuneus', 'ctx-lh-rostralanteriorcingulate', 'ctx-lh-rostralmiddlefrontal', 'ctx-lh-superiorfrontal', 'ctx-lh-superiorparietal', 'ctx-lh-superiortemporal', 'ctx-lh-supramarginal', 'ctx-lh-transversetemporal', 'ctx-lh-insula', 'ctx-rh-unknown', 'ctx-rh-caudalanteriorcingulate', 'ctx-rh-caudalmiddlefrontal', 'ctx-rh-cuneus', 'ctx-rh-entorhinal', 'ctx-rh-fusiform', 'ctx-rh-inferiorparietal', 'ctx-rh-inferiortemporal', 'ctx-rh-isthmuscingulate', 'ctx-rh-lateraloccipital', 'ctx-rh-lateralorbitofrontal', 'ctx-rh-lingual', 'ctx-rh-medialorbitofrontal', 'ctx-rh-middletemporal', 'ctx-rh-parahippocampal', 'ctx-rh-paracentral', 'ctx-rh-parsopercularis', 'ctx-rh-parsorbitalis', 'ctx-rh-parstriangularis', 'ctx-rh-pericalcarine', 'ctx-rh-postcentral', 'ctx-rh-posteriorcingulate', 'ctx-rh-precentral', 'ctx-rh-precuneus', 'ctx-rh-rostralanteriorcingulate', 'ctx-rh-rostralmiddlefrontal', 'ctx-rh-superiorfrontal', 'ctx-rh-superiorparietal', 'ctx-rh-superiortemporal', 'ctx-rh-supramarginal', 'ctx-rh-transversetemporal', 'ctx-rh-insula']
# labels:  107
# [NiftiLabelsMasker.wrapped] loading data from /workspace/home/datasets/mri/schizo_datasets/COBRE/COBRE_freesurfer/A00027787/mri/aparc.DKTatlas+aseg.nii
# [Memory]0.1s, 0.0min    : Loading _filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# (150, 107)
# (107, 107)
# /workspace/home/datasets/mri/schizo_datasets/COBRE/COBRE_fmriprep/sub-A00027969/func/sub-A00027969_task-rest_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# start
# extraction:
# (256, 256, 256)
# ['Left-Cerebral-White-Matter', 'Left-Lateral-Ventricle', 'Left-Inf-Lat-Vent', 'Left-Cerebellum-White-Matter', 'Left-Cerebellum-Cortex', 'Left-Thalamus-Proper*', 'Left-Caudate', 'Left-Putamen', 'Left-Pallidum', '3rd-Ventricle', '4th-Ventricle', 'Brain-Stem', 'Left-Hippocampus', 'Left-Amygdala', 'CSF', 'Left-Accumbens-area', 'Left-VentralDC', 'Left-vessel', 'Left-choroid-plexus', 'Right-Cerebral-White-Matter', 'Right-Cerebral-Cortex', 'Right-Lateral-Ventricle', 'Right-Inf-Lat-Vent', 'Right-Cerebellum-White-Matter', 'Right-Cerebellum-Cortex', 'Right-Thalamus-Proper*', 'Right-Caudate', 'Right-Putamen', 'Right-Pallidum', 'Right-Hippocampus', 'Right-Amygdala', 'Right-Accumbens-area', 'Right-VentralDC', 'Right-vessel', 'Right-choroid-plexus', 'WM-hypointensities', 'Optic-Chiasm', 'CC_Posterior', 'CC_Mid_Posterior', 'CC_Central', 'CC_Mid_Anterior', 'CC_Anterior', 'ctx-lh-unknown', 'ctx-lh-caudalanteriorcingulate', 'ctx-lh-caudalmiddlefrontal', 'ctx-lh-cuneus', 'ctx-lh-entorhinal', 'ctx-lh-fusiform', 'ctx-lh-inferiorparietal', 'ctx-lh-inferiortemporal', 'ctx-lh-isthmuscingulate', 'ctx-lh-lateraloccipital', 'ctx-lh-lateralorbitofrontal', 'ctx-lh-lingual', 'ctx-lh-medialorbitofrontal', 'ctx-lh-middletemporal', 'ctx-lh-parahippocampal', 'ctx-lh-paracentral', 'ctx-lh-parsopercularis', 'ctx-lh-parsorbitalis', 'ctx-lh-parstriangularis', 'ctx-lh-pericalcarine', 'ctx-lh-postcentral', 'ctx-lh-posteriorcingulate', 'ctx-lh-precentral', 'ctx-lh-precuneus', 'ctx-lh-rostralanteriorcingulate', 'ctx-lh-rostralmiddlefrontal', 'ctx-lh-superiorfrontal', 'ctx-lh-superiorparietal', 'ctx-lh-superiortemporal', 'ctx-lh-supramarginal', 'ctx-lh-transversetemporal', 'ctx-lh-insula', 'ctx-rh-unknown', 'ctx-rh-caudalanteriorcingulate', 'ctx-rh-caudalmiddlefrontal', 'ctx-rh-cuneus', 'ctx-rh-entorhinal', 'ctx-rh-fusiform', 'ctx-rh-inferiorparietal', 'ctx-rh-inferiortemporal', 'ctx-rh-isthmuscingulate', 'ctx-rh-lateraloccipital', 'ctx-rh-lateralorbitofrontal', 'ctx-rh-lingual', 'ctx-rh-medialorbitofrontal', 'ctx-rh-middletemporal', 'ctx-rh-parahippocampal', 'ctx-rh-paracentral', 'ctx-rh-parsopercularis', 'ctx-rh-parsorbitalis', 'ctx-rh-parstriangularis', 'ctx-rh-pericalcarine', 'ctx-rh-postcentral', 'ctx-rh-posteriorcingulate', 'ctx-rh-precentral', 'ctx-rh-precuneus', 'ctx-rh-rostralanteriorcingulate', 'ctx-rh-rostralmiddlefrontal', 'ctx-rh-superiorfrontal', 'ctx-rh-superiorparietal', 'ctx-rh-superiortemporal', 'ctx-rh-supramarginal', 'ctx-rh-transversetemporal', 'ctx-rh-insula']
# labels:  106
# [NiftiLabelsMasker.wrapped] loading data from /workspace/home/datasets/mri/schizo_datasets/COBRE/COBRE_freesurfer/A00027969/mri/aparc.DKTatlas+aseg.nii
# [Memory]0.1s, 0.0min    : Loading _filter_and_extract...
# ...
# labels:  107
# [NiftiLabelsMasker.wrapped] loading data from /workspace/home/datasets/mri/schizo_datasets/COBRE/COBRE_freesurfer/A00037619/mri/aparc.DKTatlas+aseg.nii
# [Memory]0.1s, 0.0min    : Loading _filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# (150, 107)
# (107, 107)
# /workspace/home/datasets/mri/schizo_datasets/COBRE/COBRE_fmriprep/sub-A00023750/func/sub-A00023750_task-rest_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# start
# extraction:
# (256, 256, 256)
# ['Left-Cerebral-White-Matter', 'Left-Lateral-Ventricle', 'Left-Inf-Lat-Vent', 'Left-Cerebellum-White-Matter', 'Left-Cerebellum-Cortex', 'Left-Thalamus-Proper*', 'Left-Caudate', 'Left-Putamen', 'Left-Pallidum', '3rd-Ventricle', '4th-Ventricle', 'Brain-Stem', 'Left-Hippocampus', 'Left-Amygdala', 'CSF', 'Left-Accumbens-area', 'Left-VentralDC', 'Left-vessel', 'Left-choroid-plexus', 'Right-Cerebral-White-Matter', 'Right-Cerebral-Cortex', 'Right-Lateral-Ventricle', 'Right-Inf-Lat-Vent', 'Right-Cerebellum-White-Matter', 'Right-Cerebellum-Cortex', 'Right-Thalamus-Proper*', 'Right-Caudate', 'Right-Putamen', 'Right-Pallidum', 'Right-Hippocampus', 'Right-Amygdala', 'Right-Accumbens-area', 'Right-VentralDC', 'Right-vessel', 'Right-choroid-plexus', 'WM-hypointensities', 'Optic-Chiasm', 'CC_Posterior', 'CC_Mid_Posterior', 'CC_Central', 'CC_Mid_Anterior', 'CC_Anterior', 'ctx-lh-unknown', 'ctx-lh-caudalanteriorcingulate', 'ctx-lh-caudalmiddlefrontal', 'ctx-lh-cuneus', 'ctx-lh-entorhinal', 'ctx-lh-fusiform', 'ctx-lh-inferiorparietal', 'ctx-lh-inferiortemporal', 'ctx-lh-isthmuscingulate', 'ctx-lh-lateraloccipital', 'ctx-lh-lateralorbitofrontal', 'ctx-lh-lingual', 'ctx-lh-medialorbitofrontal', 'ctx-lh-middletemporal', 'ctx-lh-parahippocampal', 'ctx-lh-paracentral', 'ctx-lh-parsopercularis', 'ctx-lh-parsorbitalis', 'ctx-lh-parstriangularis', 'ctx-lh-pericalcarine', 'ctx-lh-postcentral', 'ctx-lh-posteriorcingulate', 'ctx-lh-precentral', 'ctx-lh-precuneus', 'ctx-lh-rostralanteriorcingulate', 'ctx-lh-rostralmiddlefrontal', 'ctx-lh-superiorfrontal', 'ctx-lh-superiorparietal', 'ctx-lh-superiortemporal', 'ctx-lh-supramarginal', 'ctx-lh-transversetemporal', 'ctx-lh-insula', 'ctx-rh-unknown', 'ctx-rh-caudalanteriorcingulate', 'ctx-rh-caudalmiddlefrontal', 'ctx-rh-cuneus', 'ctx-rh-entorhinal', 'ctx-rh-fusiform', 'ctx-rh-inferiorparietal', 'ctx-rh-inferiortemporal', 'ctx-rh-isthmuscingulate', 'ctx-rh-lateraloccipital', 'ctx-rh-lateralorbitofrontal', 'ctx-rh-lingual', 'ctx-rh-medialorbitofrontal', 'ctx-rh-middletemporal', 'ctx-rh-parahippocampal', 'ctx-rh-paracentral', 'ctx-rh-parsopercularis', 'ctx-rh-parsorbitalis', 'ctx-rh-parstriangularis', 'ctx-rh-pericalcarine', 'ctx-rh-postcentral', 'ctx-rh-posteriorcingulate', 'ctx-rh-precentral', 'ctx-rh-precuneus', 'ctx-rh-rostralanteriorcingulate', 'ctx-rh-rostralmiddlefrontal', 'ctx-rh-superiorfrontal', 'ctx-rh-superiorparietal', 'ctx-rh-superiortemporal', 'ctx-rh-supramarginal', 'ctx-rh-transversetemporal', 'ctx-rh-insula']
# labels:  106
# [NiftiLabelsMasker.wrapped] loading data from /workspace/home/datasets/mri/schizo_datasets/COBRE/COBRE_freesurfer/A00023750/mri/aparc.DKTatlas+aseg.nii
# [Memory]0.1s, 0.0min    : Loading _filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# (150, 106)
# (106, 106)
# /workspace/home/datasets/mri/schizo_datasets/COBRE/COBRE_fmriprep/sub-A00024372/func/sub-A00024372_task-rest_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# start
# extraction:
# No such file or no access: '/workspace/home/datasets/mri/schizo_datasets/COBRE/COBRE_freesurfer/A00024372/mri/aparc.DKTatlas+aseg.nii'
# /workspace/home/datasets/mri/schizo_datasets/COBRE/COBRE_fmriprep/sub-A00024663/func/sub-A00024663_task-rest_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# start
# extraction:
# (256, 256, 256)
# ['Left-Cerebral-White-Matter', 'Left-Cerebral-Cortex', 'Left-Lateral-Ventricle', 'Left-Inf-Lat-Vent', 'Left-Cerebellum-White-Matter', 'Left-Cerebellum-Cortex', 'Left-Thalamus-Proper*', 'Left-Caudate', 'Left-Putamen', 'Left-Pallidum', '3rd-Ventricle', '4th-Ventricle', 'Brain-Stem', 'Left-Hippocampus', 'Left-Amygdala', 'CSF', 'Left-Accumbens-area', 'Left-VentralDC', 'Left-vessel', 'Left-choroid-plexus', 'Right-Cerebral-White-Matter', 'Right-Lateral-Ventricle', 'Right-Inf-Lat-Vent', 'Right-Cerebellum-White-Matter', 'Right-Cerebellum-Cortex', 'Right-Thalamus-Proper*', 'Right-Caudate', 'Right-Putamen', 'Right-Pallidum', 'Right-Hippocampus', 'Right-Amygdala', 'Right-Accumbens-area', 'Right-VentralDC', 'Right-vessel', 'Right-choroid-plexus', 'WM-hypointensities', 'Optic-Chiasm', 'CC_Posterior', 'CC_Mid_Posterior', 'CC_Central', 'CC_Mid_Anterior', 'CC_Anterior', 'ctx-lh-unknown', 'ctx-lh-caudalanteriorcingulate', 'ctx-lh-caudalmiddlefrontal', 'ctx-lh-cuneus', 'ctx-lh-entorhinal', 'ctx-lh-fusiform', 'ctx-lh-inferiorparietal', 'ctx-lh-inferiortemporal', 'ctx-lh-isthmuscingulate', 'ctx-lh-lateraloccipital', 'ctx-lh-lateralorbitofrontal', 'ctx-lh-lingual', 'ctx-lh-medialorbitofrontal', 'ctx-lh-middletemporal', 'ctx-lh-parahippocampal', 'ctx-lh-paracentral', 'ctx-lh-parsopercularis', 'ctx-lh-parsorbitalis', 'ctx-lh-parstriangularis', 'ctx-lh-pericalcarine', 'ctx-lh-postcentral', 'ctx-lh-posteriorcingulate', 'ctx-lh-precentral', 'ctx-lh-precuneus', 'ctx-lh-rostralanteriorcingulate', 'ctx-lh-rostralmiddlefrontal', 'ctx-lh-superiorfrontal', 'ctx-lh-superiorparietal', 'ctx-lh-superiortemporal', 'ctx-lh-supramarginal', 'ctx-lh-transversetemporal', 'ctx-lh-insula', 'ctx-rh-unknown', 'ctx-rh-caudalanteriorcingulate', 'ctx-rh-caudalmiddlefrontal', 'ctx-rh-cuneus', 'ctx-rh-entorhinal', 'ctx-rh-fusiform', 'ctx-rh-inferiorparietal', 'ctx-rh-inferiortemporal', 'ctx-rh-isthmuscingulate', 'ctx-rh-lateraloccipital', 'ctx-rh-lateralorbitofrontal', 'ctx-rh-lingual', 'ctx-rh-medialorbitofrontal', 'ctx-rh-middletemporal', 'ctx-rh-parahippocampal', 'ctx-rh-paracentral', 'ctx-rh-parsopercularis', 'ctx-rh-parsorbitalis', 'ctx-rh-parstriangularis', 'ctx-rh-pericalcarine', 'ctx-rh-postcentral', 'ctx-rh-posteriorcingulate', 'ctx-rh-precentral', 'ctx-rh-precuneus', 'ctx-rh-rostralanteriorcingulate', 'ctx-rh-rostralmiddlefrontal', 'ctx-rh-superiorfrontal', 'ctx-rh-superiorparietal', 'ctx-rh-superiortemporal', 'ctx-rh-supramarginal', 'ctx-rh-transversetemporal', 'ctx-rh-insula']
# labels:  106
# [NiftiLabelsMasker.wrapped] loading data from /workspace/home/datasets/mri/schizo_datasets/COBRE/COBRE_freesurfer/A00024663/mri/aparc.DKTatlas+aseg.nii
# ________________________________________________________________________________
# [Memory] Calling nilearn.maskers.base_masker._filter_and_extract...
# _filter_and_extract('/workspace/home/datasets/mri/schizo_datasets/COBRE/COBRE_fmriprep/sub-A00024663/func/sub-A00024663_task-rest_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz',
# <nilearn.maskers.nifti_labels_masker._ExtractionFunctor object at 0x7f2df57c1790>,
# { 'background_label': 0,
#   'detrend': False,
#   'dtype': None,
#   'high_pass': None,
#   'high_variance_confounds': False,
#   'labels': None,
#   'labels_img': PosixPath('/workspace/home/datasets/mri/schizo_datasets/COBRE/COBRE_freesurfer/A00024663/mri/aparc.DKTatlas+aseg.nii'),
#   'low_pass': None,
#   'mask_img': None,
#   'reports': True,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   'standardize_confounds': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': array([[-1.000000e+00,  0.000000e+00,  0.000000e+00,  1.291851e+02],
#        [ 9.313226e-10,  0.000000e+00,  1.000000e+00, -9.597167e+01],
#        [ 0.000000e+00, -1.000000e+00,  0.000000e+00,  1.404699e+02],
#        [ 0.000000e+00,  0.000000e+00,  0.000000e+00,  1.000000e+00]]),
#   'target_shape': (256, 256, 256)}, confounds=[          cosine00      cosine01      cosine02        csf     rot_x  \
# 0    6.001206e-18 -3.750753e-19 -1.500301e-18  83.061525  0.006451
# 1    6.001206e-18 -3.750753e-19 -1.500301e-18  34.740018  0.003805
# 2    1.162411e-01  1.162215e-01  1.161887e-01  10.733544  0.003208
# 3    1.161887e-01  1.160120e-01  1.157177e-01   8.789899  0.003789
# 4    1.160840e-01  1.155935e-01  1.147776e-01   3.446241  0.004859
# ..            ...           ...           ...        ...       ...
# 145 -1.157177e-01  1.141327e-01 -1.115071e-01  -7.516414 -0.004152
# 146 -1.159270e-01  1.149667e-01 -1.133722e-01  -5.685265 -0.001771
# 147 -1.160840e-01  1.155935e-01 -1.147776e-01  -5.367728 -0.000829  ..., sample_mask=None, dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=1, verbose=5)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /workspace/home/datasets/mri/schizo_datasets/COBRE/COBRE_fmriprep/sub-A00024663/func/sub-A00024663_task-rest_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Resampling images
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ____________________________________________filter_and_extract - 617.0s, 10.3min
# (150, 106)
# (106, 106)
# /workspace/home/datasets/mri/schizo_datasets/COBRE/COBRE_fmriprep/sub-A00028402/func/sub-A00028402_task-rest_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# start
# extraction:
# (256, 256, 256)
# ['Left-Cerebral-White-Matter', 'Left-Lateral-Ventricle', 'Left-Inf-Lat-Vent', 'Left-Cerebellum-White-Matter', 'Left-Cerebellum-Cortex', 'Left-Thalamus-Proper*', 'Left-Caudate', 'Left-Putamen', 'Left-Pallidum', '3rd-Ventricle', '4th-Ventricle', 'Brain-Stem', 'Left-Hippocampus', 'Left-Amygdala', 'CSF', 'Left-Accumbens-area', 'Left-VentralDC', 'Left-vessel', 'Left-choroid-plexus', 'Right-Cerebral-White-Matter', 'Right-Cerebral-Cortex', 'Right-Lateral-Ventricle', 'Right-Inf-Lat-Vent', 'Right-Cerebellum-White-Matter', 'Right-Cerebellum-Cortex', 'Right-Thalamus-Proper*', 'Right-Caudate', 'Right-Putamen', 'Right-Pallidum', 'Right-Hippocampus', 'Right-Amygdala', 'Right-Accumbens-area', 'Right-VentralDC', 'Right-vessel', 'Right-choroid-plexus', 'WM-hypointensities', 'Optic-Chiasm', 'CC_Posterior', 'CC_Mid_Posterior', 'CC_Central', 'CC_Mid_Anterior', 'CC_Anterior', 'ctx-lh-unknown', 'ctx-lh-caudalanteriorcingulate', 'ctx-lh-caudalmiddlefrontal', 'ctx-lh-cuneus', 'ctx-lh-entorhinal', 'ctx-lh-fusiform', 'ctx-lh-inferiorparietal', 'ctx-lh-inferiortemporal', 'ctx-lh-isthmuscingulate', 'ctx-lh-lateraloccipital', 'ctx-lh-lateralorbitofrontal', 'ctx-lh-lingual', 'ctx-lh-medialorbitofrontal', 'ctx-lh-middletemporal', 'ctx-lh-parahippocampal', 'ctx-lh-paracentral', 'ctx-lh-parsopercularis', 'ctx-lh-parsorbitalis', 'ctx-lh-parstriangularis', 'ctx-lh-pericalcarine', 'ctx-lh-postcentral', 'ctx-lh-posteriorcingulate', 'ctx-lh-precentral', 'ctx-lh-precuneus', 'ctx-lh-rostralanteriorcingulate', 'ctx-lh-rostralmiddlefrontal', 'ctx-lh-superiorfrontal', 'ctx-lh-superiorparietal', 'ctx-lh-superiortemporal', 'ctx-lh-supramarginal', 'ctx-lh-transversetemporal', 'ctx-lh-insula', 'ctx-rh-unknown', 'ctx-rh-caudalanteriorcingulate', 'ctx-rh-caudalmiddlefrontal', 'ctx-rh-cuneus', 'ctx-rh-entorhinal', 'ctx-rh-fusiform', 'ctx-rh-inferiorparietal', 'ctx-rh-inferiortemporal', 'ctx-rh-isthmuscingulate', 'ctx-rh-lateraloccipital', 'ctx-rh-lateralorbitofrontal', 'ctx-rh-lingual', 'ctx-rh-medialorbitofrontal', 'ctx-rh-middletemporal', 'ctx-rh-parahippocampal', 'ctx-rh-paracentral', 'ctx-rh-parsopercularis', 'ctx-rh-parsorbitalis', 'ctx-rh-parstriangularis', 'ctx-rh-pericalcarine', 'ctx-rh-postcentral', 'ctx-rh-posteriorcingulate', 'ctx-rh-precentral', 'ctx-rh-precuneus', 'ctx-rh-rostralanteriorcingulate', 'ctx-rh-rostralmiddlefrontal', 'ctx-rh-superiorfrontal', 'ctx-rh-superiorparietal', 'ctx-rh-superiortemporal', 'ctx-rh-supramarginal', 'ctx-rh-transversetemporal', 'ctx-rh-insula']
# labels:  106
# [NiftiLabelsMasker.wrapped] loading data from /workspace/home/datasets/mri/schizo_datasets/COBRE/COBRE_freesurfer/A00028402/mri/aparc.DKTatlas+aseg.nii
# ________________________________________________________________________________
# [Memory] Calling nilearn.maskers.base_masker._filter_and_extract...
# _filter_and_extract('/workspace/home/datasets/mri/schizo_datasets/COBRE/COBRE_fmriprep/sub-A00028402/func/sub-A00028402_task-rest_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz',
# <nilearn.maskers.nifti_labels_masker._ExtractionFunctor object at 0x7f2df59a99d0>,
# { 'background_label': 0,
#   'detrend': False,
#   'dtype': None,
#   'high_pass': None,
#   'high_variance_confounds': False,
#   'labels': None,
#   'labels_img': PosixPath('/workspace/home/datasets/mri/schizo_datasets/COBRE/COBRE_freesurfer/A00028402/mri/aparc.DKTatlas+aseg.nii'),
#   'low_pass': None,
#   'mask_img': None,
#   'reports': True,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   'standardize_confounds': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': array([[-9.999999e-01,  0.000000e+00,  2.279194e-09,  1.278203e+02],
#        [ 1.446551e-09,  0.000000e+00,  1.000000e+00, -8.784747e+01],
#        [ 1.862645e-09, -1.000000e+00,  0.000000e+00,  1.397623e+02],
#        [ 0.000000e+00,  0.000000e+00,  0.000000e+00,  1.000000e+00]]),
#   'target_shape': (256, 256, 256)}, confounds=[          cosine00      cosine01      cosine02        csf     rot_x  \
# 0    6.001206e-18 -3.750753e-19 -1.500301e-18  59.271588  0.000187
# 1    6.001206e-18 -3.750753e-19 -1.500301e-18  24.174492 -0.000357
# 2    1.162411e-01  1.162215e-01  1.161887e-01   7.557026  0.000867
# 3    1.161887e-01  1.160120e-01  1.157177e-01   2.205409 -0.000105
# 4    1.160840e-01  1.155935e-01  1.147776e-01   0.749919  0.000930
# ..            ...           ...           ...        ...       ...
# 145 -1.157177e-01  1.141327e-01 -1.115071e-01   4.060457 -0.000274
# 146 -1.159270e-01  1.149667e-01 -1.133722e-01   1.817782  0.000529
# 147 -1.160840e-01  1.155935e-01 -1.147776e-01   1.876630 -0.000164  ..., sample_mask=None, dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=1, verbose=5)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /workspace/home/datasets/mri/schizo_datasets/COBRE/COBRE_fmriprep/sub-A00028402/func/sub-A00028402_task-rest_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Resampling images

# %%
errrors

# %%
dataset_corr =pd.DataFrame.from_dict(corr_array)

# %%
dataset_corr.to_csv("results/cobre_dk_func_connectivity.csv", index=False)

# %%
dataset_corr
# Out:
#      b'7Networks_LH_Vis_1'-b'7Networks_LH_Vis_2'  \
# 0                                       0.469480
# 1                                       0.349527
# 2                                       0.401065
# 3                                       0.310929
# 4                                       0.188564
# ..                                           ...
# 158                                     0.559692
# 159                                     0.245285
# 160                                     0.451213
# 161                                    -0.055583
# 162                                     0.507193
#
#      b'7Networks_LH_Vis_1'-b'7Networks_LH_Vis_3'  \
# 0                                       0.243579
# 1                                       0.166937
# 2                                       0.482765
# 3                                       0.107777
# 4                                       0.492959
# ..                                           ...
# 158                                     0.295075
# 159                                     0.306978
# 160                                     0.502780
# 161                                     0.066227
# 162                                     0.753536
#
#      b'7Networks_LH_Vis_2'-b'7Networks_LH_Vis_3'  \
# 0                                      -0.130661
# 1                                       0.037780
# 2                                       0.168628
# 3                                       0.046622
# 4                                       0.301123
# ..                                           ...
# 158                                    -0.029420
# 159                                     0.219735
# 160                                     0.265650
# 161                                     0.706332
# 162                                     0.617351
#
#      b'7Networks_LH_Vis_1'-b'7Networks_LH_Vis_4'  \
# 0                                       0.297445
# 1                                       0.518068
# 2                                       0.387949
# 3                                       0.284062
# 4                                       0.502206
# ..                                           ...
# 158                                     0.365114
# 159                                     0.324521
# 160                                     0.514819
# 161                                     0.303548
# 162                                     0.773349
#
#      b'7Networks_LH_Vis_2'-b'7Networks_LH_Vis_4'  \
# 0                                       0.252037
# 1                                       0.570200
# 2                                       0.481772
# 3                                       0.422693
# 4                                       0.411595
# ..                                           ...
# 158                                     0.167520
# 159                                     0.496356
# 160                                     0.470581
# 161                                     0.433949
# 162                                     0.595832
#
#      b'7Networks_LH_Vis_3'-b'7Networks_LH_Vis_4'  \
# 0                                       0.233951
# 1                                      -0.049268
# 2                                       0.220805
# 3                                       0.137627
# 4                                       0.700059
# ..                                           ...
# 158                                     0.617846
# 159                                     0.313257
# 160                                     0.446471
# 161                                     0.620989
# 162                                     0.811537
#
#      b'7Networks_LH_Vis_1'-b'7Networks_LH_Vis_5'  \
# 0                                       0.203479
# 1                                       0.423871
# 2                                       0.393426
# 3                                       0.198176
# 4                                       0.407204
# ..                                           ...
# 158                                     0.218856
# 159                                     0.223951
# 160                                     0.439187
# 161                                     0.366222
# 162                                     0.645702
#
#      b'7Networks_LH_Vis_2'-b'7Networks_LH_Vis_5'  \
# 0                                       0.028686
# 1                                       0.470621
# 2                                       0.423376
# 3                                       0.276744
# 4                                       0.272044
# ..                                           ...
# 158                                     0.083400
# 159                                     0.156788
# 160                                     0.189752
# 161                                     0.205589
# 162                                     0.535843
#
#      b'7Networks_LH_Vis_3'-b'7Networks_LH_Vis_5'  \
# 0                                       0.631804
# 1                                       0.279740
# 2                                       0.425554
# 3                                       0.316904
# 4                                       0.527731
# ..                                           ...
# 158                                     0.713139
# 159                                     0.643565
# 160                                     0.717910
# 161                                     0.380377
# 162                                     0.740438
#
#      b'7Networks_LH_Vis_4'-b'7Networks_LH_Vis_5'  ...  \
# 0                                       0.234953  ...
# 1                                       0.579940  ...
# 2                                       0.660514  ...
# 3                                       0.371812  ...
# 4                                       0.699706  ...
# ..                                           ...  ...
# 158                                     0.713665  ...
# 159                                     0.323000  ...
# 160                                     0.552771  ...
# 161                                     0.542283  ...
# 162                                     0.782954  ...
#
#      b'7Networks_RH_Default_PFCdPFCm_13'-b'7Networks_RH_Default_pCunPCC_9'  \
# 0                                            -0.183302
# 1                                             0.202921
# 2                                             0.016336
# 3                                             0.226425
# 4                                             0.233161
# ..                                                 ...
# 158                                           0.355720
# 159                                           0.068176
# 160                                           0.138148
# 161                                           0.215773
# 162                                           0.244654
#
#      b'7Networks_RH_Default_pCunPCC_1'-b'7Networks_RH_Default_pCunPCC_9'  \
# 0                                             0.590225
# 1                                             0.345601
# 2                                             0.457874
# 3                                             0.559681
# 4                                             0.478047
# ..                                                 ...
# 158                                           0.499800
# 159                                           0.551244
# 160                                           0.482856
# 161                                           0.062470
# 162                                           0.529446
#
#      b'7Networks_RH_Default_pCunPCC_2'-b'7Networks_RH_Default_pCunPCC_9'  \
# 0                                             0.310319
# 1                                             0.262245
# 2                                             0.572041
# 3                                             0.465487
# 4                                             0.451229
# ..                                                 ...
# 158                                           0.285608
# 159                                           0.477161
# 160                                           0.070284
# 161                                           0.123570
# 162                                           0.469071
#
#      b'7Networks_RH_Default_pCunPCC_3'-b'7Networks_RH_Default_pCunPCC_9'  \
# 0                                             0.339426
# 1                                             0.378454
# 2                                             0.523497
# 3                                             0.611576
# 4                                             0.492360
# ..                                                 ...
# 158                                           0.549731
# 159                                           0.596740
# 160                                           0.416024
# 161                                           0.384804
# 162                                           0.628897
#
#      b'7Networks_RH_Default_pCunPCC_4'-b'7Networks_RH_Default_pCunPCC_9'  \
# 0                                             0.484776
# 1                                             0.136927
# 2                                             0.370256
# 3                                             0.522280
# 4                                             0.533554
# ..                                                 ...
# 158                                           0.437570
# 159                                           0.459070
# 160                                           0.144757
# 161                                          -0.009421
# 162                                           0.501287
#
#      b'7Networks_RH_Default_pCunPCC_5'-b'7Networks_RH_Default_pCunPCC_9'  \
# 0                                             0.462425
# 1                                             0.364337
# 2                                             0.563198
# 3                                             0.477719
# 4                                             0.612593
# ..                                                 ...
# 158                                           0.651632
# 159                                           0.609822
# 160                                           0.140928
# 161                                           0.229665
# 162                                           0.496010
#
#      b'7Networks_RH_Default_pCunPCC_6'-b'7Networks_RH_Default_pCunPCC_9'  \
# 0                                             0.585187
# 1                                             0.379389
# 2                                             0.669595
# 3                                             0.679843
# 4                                             0.759704
# ..                                                 ...
# 158                                           0.662262
# 159                                           0.550925
# 160                                           0.061069
# 161                                           0.215678
# 162                                           0.637444
#
#      b'7Networks_RH_Default_pCunPCC_7'-b'7Networks_RH_Default_pCunPCC_9'  \
# 0                                             0.331663
# 1                                             0.167012
# 2                                             0.481019
# 3                                             0.328467
# 4                                             0.582890
# ..                                                 ...
# 158                                           0.509567
# 159                                           0.372481
# 160                                          -0.058819
# 161                                           0.254070
# 162                                           0.306171
#
#      b'7Networks_RH_Default_pCunPCC_8'-b'7Networks_RH_Default_pCunPCC_9'  \
# 0                                             0.432210
# 1                                             0.243261
# 2                                             0.664976
# 3                                             0.632790
# 4                                             0.682155
# ..                                                 ...
# 158                                           0.634970
# 159                                           0.645473
# 160                                           0.432118
# 161                                           0.271250
# 162                                           0.553212
#
#                 id
# 0    sub-A00000838
# 1    sub-A00036844
# 2    sub-A00016197
# 3    sub-A00006754
# 4    sub-A00022509
# ..             ...
# 158  sub-A00036555
# 159  sub-A00028408
# 160  sub-A00023848
# 161  sub-A00024228
# 162  sub-A00023337
#
# [163 rows x 79801 columns]
